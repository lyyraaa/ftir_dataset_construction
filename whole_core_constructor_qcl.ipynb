# %%
import pandas as pd
import openpyxl
import h5py
import cv2
import numpy as np
import zarr
import os
import sys
sys.path.append('C:/Users/w37262do/Documents/git/PyIR/src')
import spectral_preprocessing as sp
from matplotlib import pyplot as plt

# %% [markdown]
# ## Define utility functions

# %%
def load_from_master(sheet_name):
    master = pd.read_excel(sheet_name)
    master = master[master['QCL_grid_number'] != -1]

    t_or_n = master['T or N'].to_numpy()
    slides = master['Slide'].to_numpy()
    slides_ftir = master['Slide'].to_numpy().copy();
    slides_ftir[slides_ftir == '2a'] = '2';
    slides_ftir[slides_ftir == '2b'] = '2'
    p_ids = master['Patient ID'].to_numpy()
    c_ids_ftir = master['Core Id'].to_numpy()
    c_ids_qcl = master['QCL_grid_number'].to_numpy()
    path_infos = master['path_info'].to_numpy().astype(str)
    ass = master['Ass']

    coords = master['Core Coor'].to_numpy()
    he_base = r'D:/PcrUK/H_E_segmented'
    he_filepaths = np.array([f'{he_base}/Slide {j}/{i[0]}-{i[1:]}' for i, j in zip(coords, slides)])

    hdf5_filepaths = master['File_loc_QCL'].to_numpy()
    hdf5_base = r'D:/PcrUK/QCL_data'
    old_base = r"E:\Bruker Data"
    hdf5_filepaths = np.array(
        [f'{i.replace(old_base, hdf5_base)}/zarr_data/core {j}/' for i, j in zip(hdf5_filepaths, c_ids_qcl)])

    annot_filepaths = np.array([f'{i.split("Isolated_Cores")[0]}annotations/Slide {j}/grid {k} anno.png' for i, j, k in
                                zip(hdf5_filepaths, slides, c_ids_qcl)])

    return he_filepaths, hdf5_filepaths, t_or_n, slides, p_ids, c_ids_qcl, path_infos, annot_filepaths
    
def process_core_from_path(filepath, transform):
    imported_data = zarr.open(filepath)
    core = imported_data['qcl_data'][:]
    wavenumbers = imported_data['wavenumbers'][:][np.newaxis,:]
    shape = np.array(core.shape[:-1])
    mask = np.ones(shape)
    core = core.reshape(np.prod(shape), -1); mask = mask.flatten()
    core, wavenumbers, mask = transform(core, wavenumbers, mask)
    core = core.reshape(*shape, -1); mask = mask.reshape(*shape)

    return core, wavenumbers, mask, shape

# %% [markdown]
# ## Define dataset parameters

# %%
target_width = target_height = tw = th = 360

#sheet_path = r'../lbp_3d/data/master_linked.xlsx'
sheet_path = r'D:/PcrUK/QCL_data/annotations/annotation_directory_QCL.xlsx'
he_filepaths, hdf5_filepaths, t_or_n, slides, p_ids, c_ids, path_infos, annot_filepaths = load_from_master(sheet_path)
print(f"Dataset size: {len(he_filepaths)} items")

# Define preprocessing transform
tclass = sp.QCL2024()
transform = tclass.trans_func
print(f"Using transformation: {tclass.name}")
annotation_class_colors = np.array([[0,255,0],[128,0,128],[255,0,255],[0,0,255],[255,165,0],[255,0,0],[0,255,255],[255,255,0],])#[127,0,0]])
annotation_class_names = np.array(['epithelium_n','stroma_n','epithelium_c','stroma_c','corpora_amylacea','blood',"crushed","immune_infiltrate"])#,
# Out:
# Dataset size: 230 items
# Using transformation: QCL2024

# %% [markdown]
# ## Creation loop

# %%
root_dir = r'D:/datasets/pcuk2023_qcl_whole_core'

new_sheet_data = {
    'slide':[],
    'core_id':[],
    'patient_id':[],
    't_or_n':[],
    'pathology_info':[],
    'annotated_pixels':[],
    'hdf5_filepath':[],
    'annotation_filepath':[],
    'chemical_image_filepath':[],
    'mask_filepath':[],
}

#print(f"Processing cores, on core: ",end="\r")
for core_idx in range(0,len(hdf5_filepaths)):
    # get data from master sheet
    hdf5_path = hdf5_filepaths[core_idx]
    print(f"Processing cores, on core: {core_idx+1}/{len(hdf5_filepaths)}, {hdf5_path.split('/')[-1]}",end="")
    annot_path = annot_filepaths[core_idx]
    chemical_path = annot_filepaths[core_idx].replace(" annotations"," chemical")
    tn = t_or_n[core_idx]
    pathology = path_infos[core_idx]
    s = slides[core_idx]
    p = p_ids[core_idx]
    c = c_ids[core_idx]
    
    # Load data from disk
    core,wavenumbers,mask,shape = process_core_from_path(hdf5_path,transform=transform)
    annotations = cv2.imread(annot_path)
    chemical = cv2.imread(chemical_path)
    if core is None or annotations is None or chemical is None:
        print(" skipping, missing chemical img or annotations")
        continue
    chemical = chemical[:,:,1]
    annotations = annotations[:,:,::-1]
    
    annotation_mask = np.zeros((*shape,6))
    for tissue_class in range(6):
        annotation_mask[:,:,tissue_class] = np.all(annotations == annotation_class_colors[tissue_class].reshape(1,1,-1),axis=-1)
    if annotation_mask.sum() == 0:
        print(" skipping, no annotated pixels")
        continue
    else:
        annotated_pixels = annotation_mask.sum()
        
    # pad/transform data  
    core_height,core_width,_ = core.shape
    if core_height >360:
        core = core[core_height-360:]
        chemical = chemical[core_height-360:]
        annotations = annotations[core_height-360:]
        mask = mask[core_height-360:]
    if core_width >360:
        core = core[:,core_width-360:]
        chemical = chemical[:,core_width-360:]
        annotations = annotations[:,core_width-360:]
        mask = mask[:,core_width-360:]
    core_height,core_width,_ = core.shape
    top_pad = (target_height - core_height)//2
    bot_pad = (target_height - core_height)//2 + (target_height - core_height)%2
    left_pad = (target_width - core_width)//2
    right_pad = (target_width - core_width)//2 + (target_width - core_width)%2
    core = np.pad(core,((top_pad,bot_pad),(left_pad,right_pad),(0,0)),'edge')
    mask = np.pad(mask,((top_pad,bot_pad),(left_pad,right_pad)),'constant',constant_values=0)
    annotations = np.pad(annotations,((top_pad,bot_pad),(left_pad,right_pad),(0,0)),'constant',constant_values=0)
    chemical = np.pad(chemical,((top_pad,bot_pad),(left_pad,right_pad)),'constant',constant_values=0)
    
    # save data to disk
    spectral_savepath = f'{root_dir}/spectral/s{s:0>{2}}_c{c:0>{3}}.h5'
    chemical_savepath = f'{root_dir}/chemical/s{s:0>{2}}_c{c:0>{3}}.png'
    annotation_savepath =f'{root_dir}/annotation/s{s:0>{2}}_c{c:0>{3}}.png'
    mask_savepath =f'{root_dir}/mask/s{s:0>{2}}_c{c:0>{3}}.png'
    
    hf = h5py.File(spectral_savepath, 'w')
    #hf.create_dataset('spectra', data=core, compression='lzf')
    hf.create_dataset('spectra', data=core.astype(np.float32), compression='lzf',chunks=(13,13,193))
    hf.create_dataset('mask', data=mask.astype(np.float32), compression='lzf',chunks=(13,13))
    hf.close()
    cv2.imwrite(chemical_savepath, chemical.astype(np.uint8))
    cv2.imwrite(annotation_savepath, annotations.astype(np.uint8)[:,:,::-1])
    cv2.imwrite(mask_savepath, mask.astype(np.uint8)*255)
    
    # append to mega lists
    new_sheet_data['hdf5_filepath'].append(spectral_savepath)
    new_sheet_data['annotation_filepath'].append(annotation_savepath)
    new_sheet_data['chemical_image_filepath'].append(chemical_savepath)
    new_sheet_data['mask_filepath'].append(mask_savepath)
    new_sheet_data['annotated_pixels'].append(int(annotated_pixels))
    new_sheet_data['t_or_n'].append(tn)
    new_sheet_data['pathology_info'].append(pathology)
    new_sheet_data['slide'].append(s)
    new_sheet_data['patient_id'].append(p)
    new_sheet_data['core_id'].append(c)    
    print("")
print("\n")
# Out:
# Processing cores, on core: 1/230,
# Processing cores, on core: 2/230,
# Processing cores, on core: 3/230,  skipping, no annotated pixels
# Processing cores, on core: 4/230,
# Processing cores, on core: 5/230,
# Processing cores, on core: 6/230,
# Processing cores, on core: 7/230,
# Processing cores, on core: 8/230,
# Processing cores, on core: 9/230,
# Processing cores, on core: 10/230,
# Processing cores, on core: 11/230,
# Processing cores, on core: 12/230,
# Processing cores, on core: 13/230,
# Processing cores, on core: 14/230,
# Processing cores, on core: 15/230,
# Processing cores, on core: 16/230,
# Processing cores, on core: 17/230,
# Processing cores, on core: 18/230,
# Processing cores, on core: 19/230,
# Processing cores, on core: 20/230,
# Processing cores, on core: 21/230,
# Processing cores, on core: 22/230,
# Processing cores, on core: 23/230,
# Processing cores, on core: 24/230,  skipping, no annotated pixels
# Processing cores, on core: 25/230,
# Processing cores, on core: 26/230,
# Processing cores, on core: 27/230,
# Processing cores, on core: 28/230,
# Processing cores, on core: 29/230,
# Processing cores, on core: 30/230,
# Processing cores, on core: 31/230,  skipping, no annotated pixels
# Processing cores, on core: 32/230,
# Processing cores, on core: 33/230,
# Processing cores, on core: 34/230,  skipping, no annotated pixels
# Processing cores, on core: 35/230,
# Processing cores, on core: 36/230,  skipping, no annotated pixels
# Processing cores, on core: 37/230,
# Processing cores, on core: 38/230,
# Processing cores, on core: 39/230,
# Processing cores, on core: 40/230,  skipping, no annotated pixels
# Processing cores, on core: 41/230,
# Processing cores, on core: 42/230,
# Processing cores, on core: 43/230,
# Processing cores, on core: 44/230,
# Processing cores, on core: 45/230,
# Processing cores, on core: 46/230,
# Processing cores, on core: 47/230,  skipping, no annotated pixels
# Processing cores, on core: 48/230,
# Processing cores, on core: 49/230,
# Processing cores, on core: 50/230,
# Processing cores, on core: 51/230,  skipping, no annotated pixels
# Processing cores, on core: 52/230,
# Processing cores, on core: 53/230,  skipping, no annotated pixels
# Processing cores, on core: 54/230,
# Processing cores, on core: 55/230,
# Processing cores, on core: 56/230,
# Processing cores, on core: 57/230,
# Processing cores, on core: 58/230,  skipping, no annotated pixels
# Processing cores, on core: 59/230,
# Processing cores, on core: 60/230,
# Processing cores, on core: 61/230,
# Processing cores, on core: 62/230,
# Processing cores, on core: 63/230,
# Processing cores, on core: 64/230,
# Processing cores, on core: 65/230,  skipping, no annotated pixels
# Processing cores, on core: 66/230,  skipping, no annotated pixels
# Processing cores, on core: 67/230,  skipping, no annotated pixels
# Processing cores, on core: 68/230,
# Processing cores, on core: 69/230,
# Processing cores, on core: 70/230,
# Processing cores, on core: 71/230,
# Processing cores, on core: 72/230,
# Processing cores, on core: 73/230,
# Processing cores, on core: 74/230,
# Processing cores, on core: 75/230,
# Processing cores, on core: 76/230,
# Processing cores, on core: 77/230,
# Processing cores, on core: 78/230,  skipping, no annotated pixels
# Processing cores, on core: 79/230,  skipping, no annotated pixels
# Processing cores, on core: 80/230,
# Processing cores, on core: 81/230,
# Processing cores, on core: 82/230,
# Processing cores, on core: 83/230,
# Processing cores, on core: 84/230,
# Processing cores, on core: 85/230,
# Processing cores, on core: 86/230,
# Processing cores, on core: 87/230,
# Processing cores, on core: 88/230,
# Processing cores, on core: 89/230,
# Processing cores, on core: 90/230,
# Processing cores, on core: 91/230,
# Processing cores, on core: 92/230,
# Processing cores, on core: 93/230,
# Processing cores, on core: 94/230,
# Processing cores, on core: 95/230,
# Processing cores, on core: 96/230,
# Processing cores, on core: 97/230,
# Processing cores, on core: 98/230,
# Processing cores, on core: 99/230,
# Processing cores, on core: 100/230,  skipping, no annotated pixels
# Processing cores, on core: 101/230,
# Processing cores, on core: 102/230,
# Processing cores, on core: 103/230,
# Processing cores, on core: 104/230,
# Processing cores, on core: 105/230,
# Processing cores, on core: 106/230,  skipping, no annotated pixels
# Processing cores, on core: 107/230,
# Processing cores, on core: 108/230,
# Processing cores, on core: 109/230,
# Processing cores, on core: 110/230,
# Processing cores, on core: 111/230,
# Processing cores, on core: 112/230,  skipping, no annotated pixels
# Processing cores, on core: 113/230,
# Processing cores, on core: 114/230,
# Processing cores, on core: 115/230,
# Processing cores, on core: 116/230,
# Processing cores, on core: 117/230,
# Processing cores, on core: 118/230,
# Processing cores, on core: 119/230,
# Processing cores, on core: 120/230,  skipping, no annotated pixels
# Processing cores, on core: 121/230,
# Processing cores, on core: 122/230,
# Processing cores, on core: 123/230,
# Processing cores, on core: 124/230,
# Processing cores, on core: 125/230,
# Processing cores, on core: 126/230,
# Processing cores, on core: 127/230,
# Processing cores, on core: 128/230,
# Processing cores, on core: 129/230,
# Processing cores, on core: 130/230,
# Processing cores, on core: 131/230,
# Processing cores, on core: 132/230,  skipping, no annotated pixels
# Processing cores, on core: 133/230,
# Processing cores, on core: 134/230,  skipping, no annotated pixels
# Processing cores, on core: 135/230,
# Processing cores, on core: 136/230,
# Processing cores, on core: 137/230,
# Processing cores, on core: 138/230,
# Processing cores, on core: 139/230,
# Processing cores, on core: 140/230,
# Processing cores, on core: 141/230,
# Processing cores, on core: 142/230,  skipping, no annotated pixels
# Processing cores, on core: 143/230,
# Processing cores, on core: 144/230,
# Processing cores, on core: 145/230,
# Processing cores, on core: 146/230,
# Processing cores, on core: 147/230,
# Processing cores, on core: 148/230,
# Processing cores, on core: 149/230,
# Processing cores, on core: 150/230,
# Processing cores, on core: 151/230,
# Processing cores, on core: 152/230,
# Processing cores, on core: 153/230,
# Processing cores, on core: 154/230,
# Processing cores, on core: 155/230,
# Processing cores, on core: 156/230,
# Processing cores, on core: 157/230,
# Processing cores, on core: 158/230,
# Processing cores, on core: 159/230,
# Processing cores, on core: 160/230,
# Processing cores, on core: 161/230,
# Processing cores, on core: 162/230,
# Processing cores, on core: 163/230,
# Processing cores, on core: 164/230,
# Processing cores, on core: 165/230,
# Processing cores, on core: 166/230,
# Processing cores, on core: 167/230,
# Processing cores, on core: 168/230,
# Processing cores, on core: 169/230,
# Processing cores, on core: 170/230,
# Processing cores, on core: 171/230,
# Processing cores, on core: 172/230,
# Processing cores, on core: 173/230,
# Processing cores, on core: 174/230,
# Processing cores, on core: 175/230,
# Processing cores, on core: 176/230,
# Processing cores, on core: 177/230,
# Processing cores, on core: 178/230,
# Processing cores, on core: 179/230,  skipping, no annotated pixels
# Processing cores, on core: 180/230,
# Processing cores, on core: 181/230,
# Processing cores, on core: 182/230,
# Processing cores, on core: 183/230,
# Processing cores, on core: 184/230,
# Processing cores, on core: 185/230,
# Processing cores, on core: 186/230,
# Processing cores, on core: 187/230,
# Processing cores, on core: 188/230,  skipping, no annotated pixels
# Processing cores, on core: 189/230,
# Processing cores, on core: 190/230,
# Processing cores, on core: 191/230,
# Processing cores, on core: 192/230,
# Processing cores, on core: 193/230,
# Processing cores, on core: 194/230,
# Processing cores, on core: 195/230,
# Processing cores, on core: 196/230,
# Processing cores, on core: 197/230,
# Processing cores, on core: 198/230,  skipping, no annotated pixels
# Processing cores, on core: 199/230,
# Processing cores, on core: 200/230,
# Processing cores, on core: 201/230,  skipping, no annotated pixels
# Processing cores, on core: 202/230,
# Processing cores, on core: 203/230,
# Processing cores, on core: 204/230,
# Processing cores, on core: 205/230,
# Processing cores, on core: 206/230,
# Processing cores, on core: 207/230,
# Processing cores, on core: 208/230,
# Processing cores, on core: 209/230,  skipping, no annotated pixels
# Processing cores, on core: 210/230,  skipping, no annotated pixels
# Processing cores, on core: 211/230,
# Processing cores, on core: 212/230,
# Processing cores, on core: 213/230,
# Processing cores, on core: 214/230,
# Processing cores, on core: 215/230,
# Processing cores, on core: 216/230,  skipping, no annotated pixels
# Processing cores, on core: 217/230,
# Processing cores, on core: 218/230,
# Processing cores, on core: 219/230,
# Processing cores, on core: 220/230,
# Processing cores, on core: 221/230,
# Processing cores, on core: 222/230,
# Processing cores, on core: 223/230,
# Processing cores, on core: 224/230,
# Processing cores, on core: 225/230,
# Processing cores, on core: 226/230,
# Processing cores, on core: 227/230,  skipping, no annotated pixels
# Processing cores, on core: 228/230,
# Processing cores, on core: 229/230,
# Processing cores, on core: 230/230,

# %%
df = pd.DataFrame.from_dict(new_sheet_data)
df.to_excel(fr"{root_dir}/master_sheet.xlsx",index=False)

# %%
np.save(fr"{root_dir}/mean_spectrum.npy",core[mask==1].mean(axis=(0)),)
np.save(fr"{root_dir}/std_spectrum.npy",core[mask==1].std(axis=(0)),)
np.save(fr"{root_dir}/wavenumbers.npy",wavenumbers,)
