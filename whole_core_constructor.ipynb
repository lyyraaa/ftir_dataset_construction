# %%
import pandas as pd
import openpyxl
import h5py
import cv2
import numpy as np
import os
import sys
sys.path.append('C:/Users/w37262do/Documents/git/PyIR/src')
import spectral_preprocessing as sp
from matplotlib import pyplot as plt

# %% [markdown]
# ## Define utility functions

# %%
def load_from_master(sheet_name, merge_annotations=False):
    master = pd.read_excel(sheet_name)
    he_filepaths = master['segmented HE filepath'].to_numpy()
    hdf5_filepaths = master['hdf5_filepaths'].to_numpy()

    t_or_n = master['T or N'].to_numpy()
    slides = master['Slide'].to_numpy()
    p_ids = master['Patient ID'].to_numpy()
    c_ids = master['Core Id'].to_numpy()

    path_infos = master['path_info'].to_numpy().astype(str)
    path_prepend = r'C:/Users/w37262do/Datasets/pcuk_2023/H_E_segmented'
    path_prepend_mask = r'C:/Users/w37262do/Datasets/pcuk_2023/H_E_segmented_tissuemasks'
    path_prepend_hdf5 = r'D:/workspace/code/PcrUK/PcrUK/HDF5 Data 3D'

    he_filepaths = np.array(
            [f"{path_prepend}/Slide {slides[x]}/" + he_filepath.split("/")[-1]
             for x,he_filepath in enumerate(he_filepaths)])
    mask_filepaths = np.array(
            [f"{path_prepend_mask}/Slide {slides[x]}/" + he_filepath.split("/")[-1]
             for x,he_filepath in enumerate(he_filepaths)])
    hdf5_filepaths = np.array([path_prepend_hdf5 + path.split('HDF5 Data')[-1] for path in hdf5_filepaths])
    hdf5_filepaths = np.array(
        [path.replace('D:/workspace/code/PcrUK/PcrUK', 'C:/Users/w37262do/Datasets/pcuk_2023').replace('DataCube/', '')
         for path in hdf5_filepaths])

    if not merge_annotations:
        return he_filepaths,hdf5_filepaths,mask_filepaths,t_or_n,slides,p_ids,c_ids,path_infos
    else:

        indexes = []
        indexes_keep = []
        annot_filepaths = []
        ## Load in the annotation files
        for s in list(set(slides)):
            annot_root = f'E:/workspace/code/PcrUK/PcrUK/annotations/Slide {s}/'
            for path in os.listdir(annot_root):
                if 'annotation' not in path: continue
                core_id = path.split('annotations')[0].split(' ')[-2]
                i = np.where(np.logical_and(slides == int(s), c_ids == int(core_id)))[0]
                if len(i) != 1: continue;
                indexes.append(i[0])
                indexes_keep.append(i[0])
                annot_filepaths.append(annot_root + path)

        ## Reconcile differenes between master and annotations
        indexes = np.array(indexes)
        he_filepaths = he_filepaths[indexes]
        hdf5_filepaths = hdf5_filepaths[indexes]
        t_or_n = t_or_n[indexes]
        slides = slides[indexes]
        p_ids = p_ids[indexes]
        c_ids = c_ids[indexes]
        path_infos = path_infos[indexes]
        indexes = np.arange(0, len(he_filepaths))

        return he_filepaths, hdf5_filepaths, mask_filepaths, t_or_n, slides, p_ids, c_ids, path_infos, annot_filepaths, indexes
    
def process_core_from_path(filepath,transform):
    core = h5py.File(filepath)['data/intensities'][:]
    mask = h5py.File(filepath)['data/tissue_mask'][:]
    wavenumbers = h5py.File(filepath)['data/wavenumbers'][:]
    shape = np.array(core.shape[:-1])
    core = core.reshape(np.prod(shape),-1); mask = mask.flatten()
    core, wavenumbers, mask = transform(core, wavenumbers, mask)
    core = core.reshape(*shape,-1); mask = mask.reshape(*shape)
    return core,wavenumbers,mask,shape

# %% [markdown]
# ## Define dataset parameters

# %%
target_width = target_height = tw = th = 256

sheet_path = r'../lbp_3d/data/master_linked.xlsx'
he_filepaths, hdf5_filepaths, mask_filepaths, t_or_n, slides, p_ids, c_ids, path_infos, annot_filepaths, indexes = load_from_master(sheet_path,merge_annotations=True)
print(f"Dataset size: {len(he_filepaths)} items")

# Define preprocessing transform
tclass = sp.DougalPipeline1_2ndderiv(
    np.load("C:/Users/w37262do/Documents/git/csegnet_pcr/model/pre_dougal_mean.npy"),
    np.load("C:/Users/w37262do/Documents/git/csegnet_pcr/model/pre_dougal_loadings.npy"))
transform = tclass.trans_func
print(f"Using transformation: {tclass.name}")
annotation_class_colors = np.array([[0,255,0],[128,0,128],[255,0,255],[0,0,255],[255,165,0],[255,0,0],[0,255,255],[255,255,0],])#[127,0,0]])
annotation_class_names = np.array(['epithelium_n','stroma_n','epithelium_c','stroma_c','corpora_amylacea','blood',"crushed","immune_infiltrate"])#,
# Out:
# Dataset size: 235 items
# Using transformation: Dougal Transform 1, 2nd derivative

# %% [markdown]
# ## Creation loop

# %%
root_dir = r'D:/datasets/pcuk2023_ftir_whole_core'

new_sheet_data = {
    'slide':[],
    'core_id':[],
    'patient_id':[],
    't_or_n':[],
    'pathology_info':[],
    'annotated_pixels':[],
    'hdf5_filepath':[],
    'annotation_filepath':[],
    'chemical_image_filepath':[],
    'mask_filepath':[],
}

#print(f"Processing cores, on core: ",end="\r")
for core_idx in range(0,len(hdf5_filepaths)):
    # get data from master sheet
    hdf5_path = hdf5_filepaths[core_idx]
    print(f"Processing cores, on core: {core_idx+1}/{len(hdf5_filepaths)}, {hdf5_path.split('/')[-1]}",end="")
    annot_path = annot_filepaths[core_idx]
    chemical_path = annot_filepaths[core_idx].replace(" annotations"," chemical")
    tn = t_or_n[core_idx]
    pathology = path_infos[core_idx]
    s = slides[core_idx]
    p = p_ids[core_idx]
    c = c_ids[core_idx]
    
    # Load data from disk
    core,wavenumbers,mask,shape = process_core_from_path(hdf5_path,transform=transform)
    annotations = cv2.imread(annot_path)
    chemical = cv2.imread(chemical_path)
    if core is None or annotations is None or chemical is None:
        print(" skipping, missing chemical img or annotations")
        continue
    chemical = chemical[:,:,1]
    annotations = annotations[:,:,::-1]
    
    annotation_mask = np.zeros((*shape,6))
    for tissue_class in range(6):
        annotation_mask[:,:,tissue_class] = np.all(annotations == annotation_class_colors[tissue_class].reshape(1,1,-1),axis=-1)
    if annotation_mask.sum() == 0:
        print(" skipping, no annotated pixels")
        continue
    else:
        annotated_pixels = annotation_mask.sum()
        
    # pad/transform data  
    core_height,core_width,_ = core.shape
    if core_height >256:
        core = core[core_height-256:]
        chemical = chemical[core_height-256:]
        annotations = annotations[core_height-256:]
        mask = mask[core_height-256:]
    if core_width >256:
        core = core[:,core_width-256:]
        chemical = chemical[:,core_width-256:]
        annotations = annotations[:,core_width-256:]
        mask = mask[:,core_width-256:]
    core_height,core_width,_ = core.shape
    top_pad = (target_height - core_height)//2
    bot_pad = (target_height - core_height)//2 + (target_height - core_height)%2
    left_pad = (target_width - core_width)//2
    right_pad = (target_width - core_width)//2 + (target_width - core_width)%2
    core = np.pad(core,((top_pad,bot_pad),(left_pad,right_pad),(0,0)),'edge')
    mask = np.pad(mask,((top_pad,bot_pad),(left_pad,right_pad)),'constant',constant_values=0)
    annotations = np.pad(annotations,((top_pad,bot_pad),(left_pad,right_pad),(0,0)),'constant',constant_values=0)
    chemical = np.pad(chemical,((top_pad,bot_pad),(left_pad,right_pad)),'constant',constant_values=0)
    
    # save data to disk
    spectral_savepath = f'{root_dir}/spectral/s{s:0>{2}}_c{c:0>{3}}.h5'
    chemical_savepath = f'{root_dir}/chemical/s{s:0>{2}}_c{c:0>{3}}.png'
    annotation_savepath =f'{root_dir}/annotation/s{s:0>{2}}_c{c:0>{3}}.png'
    mask_savepath =f'{root_dir}/mask/s{s:0>{2}}_c{c:0>{3}}.png'
    
    hf = h5py.File(spectral_savepath, 'w')
    #hf.create_dataset('spectra', data=core, compression='lzf')
    hf.create_dataset('spectra', data=core.astype(np.float32), compression='lzf',chunks=(13,13,193))
    hf.create_dataset('mask', data=mask.astype(np.float32), compression='lzf',chunks=(13,13))
    hf.close()
    cv2.imwrite(chemical_savepath, chemical.astype(np.uint8))
    cv2.imwrite(annotation_savepath, annotations.astype(np.uint8)[:,:,::-1])
    cv2.imwrite(mask_savepath, mask.astype(np.uint8)*255)
    
    # append to mega lists
    new_sheet_data['hdf5_filepath'].append(spectral_savepath)
    new_sheet_data['annotation_filepath'].append(annotation_savepath)
    new_sheet_data['chemical_image_filepath'].append(chemical_savepath)
    new_sheet_data['mask_filepath'].append(mask_savepath)
    new_sheet_data['annotated_pixels'].append(int(annotated_pixels))
    new_sheet_data['t_or_n'].append(tn)
    new_sheet_data['pathology_info'].append(pathology)
    new_sheet_data['slide'].append(s)
    new_sheet_data['patient_id'].append(p)
    new_sheet_data['core_id'].append(c)    
    print("")
print("\n")
# Out:
# Processing cores, on core: 1/235, c10_p159aT
# Processing cores, on core: 2/235, c12_p111cN
# Processing cores, on core: 3/235, c14_p114aN
# Processing cores, on core: 4/235, c16_p106bT
# Processing cores, on core: 5/235, c23_p114aT
# Processing cores, on core: 6/235, c24_p97aT
# Processing cores, on core: 7/235, c32_p114aT
# Processing cores, on core: 8/235, c33_p110aT
# Processing cores, on core: 9/235, c39_p97aT
# Processing cores, on core: 10/235, c41_p111cN
# Processing cores, on core: 11/235, c44_p110aT
# Processing cores, on core: 12/235, c48_p106bT
# Processing cores, on core: 13/235, c5_p425aN
# Processing cores, on core: 14/235, c51_p110aN
# Processing cores, on core: 15/235, c53_p73aN
# Processing cores, on core: 16/235, c54_p159aN
# Processing cores, on core: 17/235, c59_p111cT
# Processing cores, on core: 18/235, c61_p97aT
# Processing cores, on core: 19/235, c62_p97aN
# Processing cores, on core: 20/235, c65_p106bN
# Processing cores, on core: 21/235, c67_p110aT
# Processing cores, on core: 22/235, c70_p111cT
# Processing cores, on core: 23/235, c74_p114aT skipping, no annotated pixels
# Processing cores, on core: 24/235, c76_p159aT
# Processing cores, on core: 25/235, c10_p452aN
# Processing cores, on core: 26/235, c12_p445eN
# Processing cores, on core: 27/235, c15_p430aN
# Processing cores, on core: 28/235, c16_p470bT
# Processing cores, on core: 29/235, c25_p470bT
# Processing cores, on core: 30/235, c47_p470bT
# Processing cores, on core: 31/235, c50_p374aN
# Processing cores, on core: 32/235, c56_p423aN
# Processing cores, on core: 33/235, c60_p421aT
# Processing cores, on core: 34/235, c64_p421aT
# Processing cores, on core: 35/235, c8_p421aT
# Processing cores, on core: 36/235, c1_p424aT
# Processing cores, on core: 37/235, c13_p422aT
# Processing cores, on core: 38/235, c29_p424aN
# Processing cores, on core: 39/235, c41_p424aT
# Processing cores, on core: 40/235, c42_p422bN
# Processing cores, on core: 41/235, c58_p422aT
# Processing cores, on core: 42/235, c30_p524bT
# Processing cores, on core: 43/235, c31_p491bN
# Processing cores, on core: 44/235, c47_p491aT
# Processing cores, on core: 45/235, c48_p494aN
# Processing cores, on core: 46/235, c49_p524bT
# Processing cores, on core: 47/235, c51_p494aT
# Processing cores, on core: 48/235, c58_p524aN
# Processing cores, on core: 49/235, c15_p15aN
# Processing cores, on core: 50/235, c22_p15aT skipping, no annotated pixels
# Processing cores, on core: 51/235, c29_p16aN
# Processing cores, on core: 52/235, c33_p52cN
# Processing cores, on core: 53/235, c37_p471aT
# Processing cores, on core: 54/235, c39_p36aN
# Processing cores, on core: 55/235, c48_p471bT
# Processing cores, on core: 56/235, c59_p51bN
# Processing cores, on core: 57/235, c75_p23aT
# Processing cores, on core: 58/235, c80_p22bT
# Processing cores, on core: 59/235, c10_p18aT
# Processing cores, on core: 60/235, c12_p18aT skipping, no annotated pixels
# Processing cores, on core: 61/235, c13_p77aN
# Processing cores, on core: 62/235, c14_p18bN
# Processing cores, on core: 63/235, c16_p67aN
# Processing cores, on core: 64/235, c19_p31cT
# Processing cores, on core: 65/235, c25_p67aT
# Processing cores, on core: 66/235, c26_p67aT
# Processing cores, on core: 67/235, c27_p31dT
# Processing cores, on core: 68/235, c36_p18aN
# Processing cores, on core: 69/235, c57_p67aT
# Processing cores, on core: 70/235, c67_p67aN
# Processing cores, on core: 71/235, c22_p45bN
# Processing cores, on core: 72/235, c33_p16aT
# Processing cores, on core: 73/235, c40_p59aN
# Processing cores, on core: 74/235, c42_p36aT
# Processing cores, on core: 75/235, c5_p39bT
# Processing cores, on core: 76/235, c69_p65bN
# Processing cores, on core: 77/235, c88_p88aT
# Processing cores, on core: 78/235, c1_p64aN
# Processing cores, on core: 79/235, c20_p600bN
# Processing cores, on core: 80/235, c38_p600bT
# Processing cores, on core: 81/235, c5_p600bT
# Processing cores, on core: 82/235, c23_p561aN
# Processing cores, on core: 83/235, c25_p613bN
# Processing cores, on core: 84/235, c28_p568aT skipping, no annotated pixels
# Processing cores, on core: 85/235, c47_p551aN
# Processing cores, on core: 86/235, c54_p568aT
# Processing cores, on core: 87/235, c56_p568aT
# Processing cores, on core: 88/235, c15_p29bT
# Processing cores, on core: 89/235, c24_p14aN
# Processing cores, on core: 90/235, c4_p29bN
# Processing cores, on core: 91/235, c45_p29aT
# Processing cores, on core: 92/235, c48_p14bT
# Processing cores, on core: 93/235, c31_p482aT
# Processing cores, on core: 94/235, c36_p489aN
# Processing cores, on core: 95/235, c38_p510aN
# Processing cores, on core: 96/235, c45_p496bT
# Processing cores, on core: 97/235, c51_p473bN
# Processing cores, on core: 98/235, c64_p482bT
# Processing cores, on core: 99/235, c9_p496bT
# Processing cores, on core: 100/235, c9_p496bT
# Processing cores, on core: 101/235, c11_p399bT
# Processing cores, on core: 102/235, c13_p468aN
# Processing cores, on core: 103/235, c17_p461aT
# Processing cores, on core: 104/235, c18_p430aN
# Processing cores, on core: 105/235, c34_p461bT
# Processing cores, on core: 106/235, c39_p461aT
# Processing cores, on core: 107/235, c50_p469cN
# Processing cores, on core: 108/235, c32_p124bT
# Processing cores, on core: 109/235, c45_p144aT
# Processing cores, on core: 110/235, c7_p146cN
# Processing cores, on core: 111/235, c83_p124aT
# Processing cores, on core: 112/235, c84_p144aT
# Processing cores, on core: 113/235, c85_p108bN
# Processing cores, on core: 114/235, c1_p108aN
# Processing cores, on core: 115/235, c35_p143aN
# Processing cores, on core: 116/235, c38_p112bN
# Processing cores, on core: 117/235, c50_p33aN
# Processing cores, on core: 118/235, c51_p190aT skipping, no annotated pixels
# Processing cores, on core: 119/235, c53_p61aT
# Processing cores, on core: 120/235, c54_p337sT
# Processing cores, on core: 121/235, c58_p61aT
# Processing cores, on core: 122/235, c72_p217bN
# Processing cores, on core: 123/235, c92_p337aT
# Processing cores, on core: 124/235, c15_p7bT
# Processing cores, on core: 125/235, c24_p16aN
# Processing cores, on core: 126/235, c66_p59bN
# Processing cores, on core: 127/235, c73_p44bN
# Processing cores, on core: 128/235, c77_p7bN
# Processing cores, on core: 129/235, c9_p9aT
# Processing cores, on core: 130/235, c90_p88aT
# Processing cores, on core: 131/235, c91_p44bT
# Processing cores, on core: 132/235, c14_p603bN
# Processing cores, on core: 133/235, c20_p603bT
# Processing cores, on core: 134/235, c56_p496bN
# Processing cores, on core: 135/235, c8_p496bT
# Processing cores, on core: 136/235, c13_p561aT
# Processing cores, on core: 137/235, c14_p556bT
# Processing cores, on core: 138/235, c16_p540bN
# Processing cores, on core: 139/235, c18_p556bT
# Processing cores, on core: 140/235, c22_p561bT
# Processing cores, on core: 141/235, c34_p561aT
# Processing cores, on core: 142/235, c39_p613aN
# Processing cores, on core: 143/235, c43_p538aN
# Processing cores, on core: 144/235, c46_p563bN
# Processing cores, on core: 145/235, c62_p617aN
# Processing cores, on core: 146/235, c13_p504bN
# Processing cores, on core: 147/235, c19_p24bN
# Processing cores, on core: 148/235, c41_p113aN
# Processing cores, on core: 149/235, c46_p113aT
# Processing cores, on core: 150/235, c1_p108aN
# Processing cores, on core: 151/235, c10_p123aN
# Processing cores, on core: 152/235, c12_p415aT
# Processing cores, on core: 153/235, c14_p144bT
# Processing cores, on core: 154/235, c16_p123bN
# Processing cores, on core: 155/235, c17_p146bT
# Processing cores, on core: 156/235, c18_p190aT
# Processing cores, on core: 157/235, c19_p401aN
# Processing cores, on core: 158/235, c2_p61aT
# Processing cores, on core: 159/235, c22_p112bN
# Processing cores, on core: 160/235, c23_p124bN
# Processing cores, on core: 161/235, c24_p226aT
# Processing cores, on core: 162/235, c3_p405aN
# Processing cores, on core: 163/235, c31_p124bT
# Processing cores, on core: 164/235, c32_p33bN
# Processing cores, on core: 165/235, c33_p112aT
# Processing cores, on core: 166/235, c36_p224aN
# Processing cores, on core: 167/235, c40_p144aT
# Processing cores, on core: 168/235, c41_p142sT
# Processing cores, on core: 169/235, c48_p208aT
# Processing cores, on core: 170/235, c49_p190aT
# Processing cores, on core: 171/235, c54_p61aT
# Processing cores, on core: 172/235, c56_p226aT
# Processing cores, on core: 173/235, c60_p119aN
# Processing cores, on core: 174/235, c61_p337sT
# Processing cores, on core: 175/235, c67_p405aN
# Processing cores, on core: 176/235, c69_p142aT
# Processing cores, on core: 177/235, c75_p208bT
# Processing cores, on core: 178/235, c79_p224aN
# Processing cores, on core: 179/235, c80_p108bN
# Processing cores, on core: 180/235, c82_p337aT
# Processing cores, on core: 181/235, c83_p405bN
# Processing cores, on core: 182/235, c9_p146aN
# Processing cores, on core: 183/235, c92_p415aN
# Processing cores, on core: 184/235, c10_p459aN
# Processing cores, on core: 185/235, c14_p399bT
# Processing cores, on core: 186/235, c15_p421aT
# Processing cores, on core: 187/235, c19_p454aT
# Processing cores, on core: 188/235, c21_p449bN
# Processing cores, on core: 189/235, c24_p423aT
# Processing cores, on core: 190/235, c25_p418aT
# Processing cores, on core: 191/235, c27_p433aT
# Processing cores, on core: 192/235, c30_p469aN
# Processing cores, on core: 193/235, c33_p449aN
# Processing cores, on core: 194/235, c41_p464aN
# Processing cores, on core: 195/235, c43_p471aT
# Processing cores, on core: 196/235, c48_p471aT
# Processing cores, on core: 197/235, c49_p454aT
# Processing cores, on core: 198/235, c51_p399aT
# Processing cores, on core: 199/235, c52_p459bN
# Processing cores, on core: 200/235, c55_p464bN
# Processing cores, on core: 201/235, c56_p454aT
# Processing cores, on core: 202/235, c60_p472aN
# Processing cores, on core: 203/235, c61_p469cN
# Processing cores, on core: 204/235, c62_p370aT
# Processing cores, on core: 205/235, c65_p433aT
# Processing cores, on core: 206/235, c66_p421aT skipping, no annotated pixels
# Processing cores, on core: 207/235, c70_p421aT skipping, no annotated pixels
# Processing cores, on core: 208/235, c8_p471aT
# Processing cores, on core: 209/235, c10_p615bN
# Processing cores, on core: 210/235, c12_p540bN
# Processing cores, on core: 211/235, c14_p556bT
# Processing cores, on core: 212/235, c15_p559bN
# Processing cores, on core: 213/235, c16_p540bN
# Processing cores, on core: 214/235, c18_p556bT
# Processing cores, on core: 215/235, c19_p561aN
# Processing cores, on core: 216/235, c24_p617bN
# Processing cores, on core: 217/235, c27_p519aT
# Processing cores, on core: 218/235, c33_p617aT
# Processing cores, on core: 219/235, c35_p563bT
# Processing cores, on core: 220/235, c38_p609aT
# Processing cores, on core: 221/235, c4_p516aN
# Processing cores, on core: 222/235, c44_p609aT
# Processing cores, on core: 223/235, c45_p516aT
# Processing cores, on core: 224/235, c49_p523aN
# Processing cores, on core: 225/235, c50_p615aT
# Processing cores, on core: 226/235, c52_p523bT
# Processing cores, on core: 227/235, c53_p538bN
# Processing cores, on core: 228/235, c55_p523aT
# Processing cores, on core: 229/235, c59_p615dN
# Processing cores, on core: 230/235, c61_p516aN
# Processing cores, on core: 231/235, c65_p519aT
# Processing cores, on core: 232/235, c67_p516aT
# Processing cores, on core: 233/235, c7_p563aN
# Processing cores, on core: 234/235, c70_p556bT
# Processing cores, on core: 235/235, c72_p519aT

# %%
df = pd.DataFrame.from_dict(new_sheet_data)
df.to_excel(fr"{root_dir}/master_sheet.xlsx",index=False)
