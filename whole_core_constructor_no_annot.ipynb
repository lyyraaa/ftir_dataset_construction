# %%
import pandas as pd
import openpyxl
import h5py
import cv2
import numpy as np
import os
import sys
sys.path.append('C:/Users/w37262do/Documents/git/PyIR/src')
import spectral_preprocessing as sp
from matplotlib import pyplot as plt
import pyir_spectralcollection as pyir
kit = pyir.PyIR_SpectralCollection()

# %% [markdown]
# ## Define utility functions

# %%
def load_from_master(sheet_name, merge_annotations=False):
    master = pd.read_excel(sheet_name)
    he_filepaths = master['segmented HE filepath'].to_numpy()
    hdf5_filepaths = master['hdf5_filepaths'].to_numpy()

    t_or_n = master['T or N'].to_numpy()
    slides = master['Slide'].to_numpy()
    p_ids = master['Patient ID'].to_numpy()
    c_ids = master['Core Id'].to_numpy()

    path_infos = master['path_info'].to_numpy().astype(str)
    path_prepend = r'C:/Users/w37262do/Datasets/pcuk_2023/H_E_segmented'
    path_prepend_mask = r'C:/Users/w37262do/Datasets/pcuk_2023/H_E_segmented_tissuemasks'
    path_prepend_hdf5 = r'D:/workspace/code/PcrUK/PcrUK/HDF5 Data 3D'

    he_filepaths = np.array(
            [f"{path_prepend}/Slide {slides[x]}/" + he_filepath.split("/")[-1]
             for x,he_filepath in enumerate(he_filepaths)])
    mask_filepaths = np.array(
            [f"{path_prepend_mask}/Slide {slides[x]}/" + he_filepath.split("/")[-1]
             for x,he_filepath in enumerate(he_filepaths)])
    hdf5_filepaths = np.array([path_prepend_hdf5 + path.split('HDF5 Data')[-1] for path in hdf5_filepaths])
    hdf5_filepaths = np.array(
        [path.replace('D:/workspace/code/PcrUK/PcrUK', 'C:/Users/w37262do/Datasets/pcuk_2023').replace('DataCube/', '')
         for path in hdf5_filepaths])

    if not merge_annotations:
        return he_filepaths,hdf5_filepaths,mask_filepaths,t_or_n,slides,p_ids,c_ids,path_infos
    else:

        indexes = []
        indexes_keep = []
        annot_filepaths = []
        ## Load in the annotation files
        for s in list(set(slides)):
            annot_root = f'E:/workspace/code/PcrUK/PcrUK/annotations/Slide {s}/'
            for path in os.listdir(annot_root):
                if 'annotation' not in path: continue
                core_id = path.split('annotations')[0].split(' ')[-2]
                i = np.where(np.logical_and(slides == int(s), c_ids == int(core_id)))[0]
                if len(i) != 1: continue;
                indexes.append(i[0])
                indexes_keep.append(i[0])
                annot_filepaths.append(annot_root + path)

        ## Reconcile differenes between master and annotations
        indexes = np.array(indexes)
        he_filepaths = he_filepaths[indexes]
        hdf5_filepaths = hdf5_filepaths[indexes]
        t_or_n = t_or_n[indexes]
        slides = slides[indexes]
        p_ids = p_ids[indexes]
        c_ids = c_ids[indexes]
        path_infos = path_infos[indexes]
        indexes = np.arange(0, len(he_filepaths))

        return he_filepaths, hdf5_filepaths, mask_filepaths, t_or_n, slides, p_ids, c_ids, path_infos, annot_filepaths, indexes
    
def process_core_from_path(filepath,transform):
    core = h5py.File(filepath)['data/intensities'][:]
    mask = h5py.File(filepath)['data/tissue_mask'][:]
    wavenumbers = h5py.File(filepath)['data/wavenumbers'][:]
    shape = np.array(core.shape[:-1])
    core = core.reshape(np.prod(shape),-1); mask = mask.flatten()
    core, wavenumbers, mask = transform(core, wavenumbers, mask)
    core = core.reshape(*shape,-1); mask = mask.reshape(*shape)
    return core,wavenumbers,mask,shape

# %% [markdown]
# ## Define dataset parameters

# %%
target_width = target_height = tw = th = 256

sheet_path = r'../lbp_3d/data/master_linked.xlsx'
he_filepaths, hdf5_filepaths, mask_filepaths, t_or_n, slides, p_ids, c_ids, path_infos = load_from_master(sheet_path,merge_annotations=False)
print(f"Dataset size: {len(he_filepaths)} items")

# Define preprocessing transform
tclass = sp.DougalPipeline1_2ndderiv(
    np.load("C:/Users/w37262do/Documents/git/csegnet_pcr/model/pre_dougal_mean.npy"),
    np.load("C:/Users/w37262do/Documents/git/csegnet_pcr/model/pre_dougal_loadings.npy"))
transform = tclass.trans_func
print(f"Using transformation: {tclass.name}")
annotation_class_colors = np.array([[0,255,0],[128,0,128],[255,0,255],[0,0,255],[255,165,0],[255,0,0],[0,255,255],[255,255,0],])#[127,0,0]])
annotation_class_names = np.array(['epithelium_n','stroma_n','epithelium_c','stroma_c','corpora_amylacea','blood',"crushed","immune_infiltrate"])#,
# Out:
# Dataset size: 1095 items
# Using transformation: Dougal Transform 1, 2nd derivative

# %%
tclass_chemical = sp.TestForChemical(
    np.load("C:/Users/w37262do/Documents/git/csegnet_pcr/model/pre_dougal_mean.npy"),
    np.load("C:/Users/w37262do/Documents/git/csegnet_pcr/model/pre_dougal_loadings.npy")
)
chemical_transform = tclass_chemical.trans_func

# %% [markdown]
# ## Creation loop

# %%
root_dir = r'D:/datasets/pcuk2023_ftir_all'

new_sheet_data = {
    'slide':[],
    'core_id':[],
    'patient_id':[],
    't_or_n':[],
    'pathology_info':[],
    'hdf5_filepath':[],
    'chemical_image_filepath':[],
    'mask_filepath':[],
}

#print(f"Processing cores, on core: ",end="\r")
for core_idx in range(0,len(hdf5_filepaths)):
    # get data from master sheet
    #hdf5_path = hdf5_filepaths[core_idx].replace()
    path = hdf5_filepaths[core_idx].split('/')[-2:]
    hdf5_path = 'D:/PcrUK/HDF5 Data 3D/' + path[0] + "/DataCube/" + path[1]
    print(f"Processing cores, on core: {core_idx+1}/{len(hdf5_filepaths)}, {hdf5_path.split('/')[-1]}",end="")
    #chemical_path = annot_filepaths[core_idx].replace(" annotations"," chemical")
    chempath = hdf5_path.replace("DataCube","chemicalImage").split('/')
    chemical_path = "/".join(chempath[:-1]) + "/" + chempath[-1].split("_")[0][1:] + ".tif"
    tn = t_or_n[core_idx]
    pathology = path_infos[core_idx]
    s = slides[core_idx]
    p = p_ids[core_idx]
    c = c_ids[core_idx]
    
    # Load data from disk
    core,wavenumbers,mask,shape = process_core_from_path(hdf5_path,transform=transform)
    
    chemical,chemical_wavenumbers,_,chem_shape = process_core_from_path(hdf5_path,transform=chemical_transform)
    chemical = kit.area_between(1700,1600,data=chemical,wavenums=chemical_wavenumbers).reshape(*chem_shape)
    chemical[chemical<0] = 0
    chemical[chemical>13] = 13
    chemical /= chemical.max()
    chemical *= 255
    chemical = np.rint(chemical).astype(np.uint8)
    if core is None or chemical is None:
        print(" skipping, missing chemical img or annotations")
        continue
        
    # pad/transform data  
    core_height,core_width,_ = core.shape
    if core_height >256:
        core = core[core_height-256:]
        chemical = chemical[core_height-256:]
        mask = mask[core_height-256:]
    if core_width >256:
        core = core[:,core_width-256:]
        chemical = chemical[:,core_width-256:]
        mask = mask[:,core_width-256:]
    core_height,core_width,_ = core.shape
    top_pad = (target_height - core_height)//2
    bot_pad = (target_height - core_height)//2 + (target_height - core_height)%2
    left_pad = (target_width - core_width)//2
    right_pad = (target_width - core_width)//2 + (target_width - core_width)%2
    core = np.pad(core,((top_pad,bot_pad),(left_pad,right_pad),(0,0)),'edge')
    mask = np.pad(mask,((top_pad,bot_pad),(left_pad,right_pad)),'constant',constant_values=0)
    chemical = np.pad(chemical,((top_pad,bot_pad),(left_pad,right_pad)),'constant',constant_values=0)
    
    # save data to disk
    spectral_savepath = f'{root_dir}/spectral/s{s:0>{2}}_c{c:0>{3}}.h5'
    chemical_savepath = f'{root_dir}/chemical/s{s:0>{2}}_c{c:0>{3}}.png'
    mask_savepath =f'{root_dir}/mask/s{s:0>{2}}_c{c:0>{3}}.png'
    
    hf = h5py.File(spectral_savepath, 'w')
    #hf.create_dataset('spectra', data=core, compression='lzf')
    hf.create_dataset('spectra', data=core.astype(np.float32), compression='lzf',chunks=(13,13,193))
    hf.create_dataset('mask', data=mask.astype(np.float32), compression='lzf',chunks=(13,13))
    hf.close()
    cv2.imwrite(chemical_savepath, chemical.astype(np.uint8))
    cv2.imwrite(mask_savepath, mask.astype(np.uint8)*255)
    
    # append to mega lists
    new_sheet_data['hdf5_filepath'].append(spectral_savepath)
    new_sheet_data['chemical_image_filepath'].append(chemical_savepath)
    new_sheet_data['mask_filepath'].append(mask_savepath)
    new_sheet_data['t_or_n'].append(tn)
    new_sheet_data['pathology_info'].append(pathology)
    new_sheet_data['slide'].append(s)
    new_sheet_data['patient_id'].append(p)
    new_sheet_data['core_id'].append(c)    
    print("")
print("\n")
# Out:
# Processing cores, on core: 1/1095, c4_p49bT
# Processing cores, on core: 2/1095, c70_p111cT
# Processing cores, on core: 3/1095, c14_p114aN
# Processing cores, on core: 4/1095, c23_p114aT
# Processing cores, on core: 5/1095, c32_p114aT
# Processing cores, on core: 6/1095, c74_p114aT
# Processing cores, on core: 7/1095, c42_p145aN
# Processing cores, on core: 8/1095, c52_p145aN
# Processing cores, on core: 9/1095, c57_p145aN
# Processing cores, on core: 10/1095, c10_p159aT
# Processing cores, on core: 11/1095, c45_p159aT
# Processing cores, on core: 12/1095, c54_p159aN
# Processing cores, on core: 13/1095, c75_p159aN
# Processing cores, on core: 14/1095, c5_p425aN
# Processing cores, on core: 15/1095, c7_p425aT
# Processing cores, on core: 16/1095, c8_p425aT
# Processing cores, on core: 17/1095, c35_p425aN
# Processing cores, on core: 18/1095, c58_p425aT
# Processing cores, on core: 19/1095, c11_p580aN
# Processing cores, on core: 20/1095, c28_p580aN
# Processing cores, on core: 21/1095, c43_p580aN
# Processing cores, on core: 22/1095, c9_p606aN
# Processing cores, on core: 23/1095, c60_p606aN
# Processing cores, on core: 24/1095, c66_p606aN
# Processing cores, on core: 25/1095, c69_p111cN
# Processing cores, on core: 26/1095, c59_p111cT
# Processing cores, on core: 27/1095, c76_p159aT
# Processing cores, on core: 28/1095, c12_p111cN
# Processing cores, on core: 29/1095, c41_p111cN
# Processing cores, on core: 30/1095, c63_p49bT
# Processing cores, on core: 31/1095, c73_p49bT
# Processing cores, on core: 32/1095, c27_p73aN
# Processing cores, on core: 33/1095, c29_p73aN
# Processing cores, on core: 34/1095, c49_p73aN
# Processing cores, on core: 35/1095, c53_p73aN
# Processing cores, on core: 36/1095, c24_p97aT
# Processing cores, on core: 37/1095, c26_p97aN
# Processing cores, on core: 38/1095, c39_p97aT
# Processing cores, on core: 39/1095, c61_p97aT
# Processing cores, on core: 40/1095, c62_p97aN
# Processing cores, on core: 41/1095, c17_p97aN
# Processing cores, on core: 42/1095, c6_p110aN
# Processing cores, on core: 43/1095, c48_p106bT
# Processing cores, on core: 44/1095, c65_p106bN
# Processing cores, on core: 45/1095, c37_p109aN
# Processing cores, on core: 46/1095, c40_p109aN
# Processing cores, on core: 47/1095, c68_p109aN
# Processing cores, on core: 48/1095, c71_p109aT
# Processing cores, on core: 49/1095, c33_p110aT
# Processing cores, on core: 50/1095, c44_p110aT
# Processing cores, on core: 51/1095, c51_p110aN
# Processing cores, on core: 52/1095, c16_p106bT
# Processing cores, on core: 53/1095, c67_p110aT
# Processing cores, on core: 54/1095, c57_p460bT
# Processing cores, on core: 55/1095, c14_p461aT
# Processing cores, on core: 56/1095, c30_p453bN
# Processing cores, on core: 57/1095, c33_p464aN
# Processing cores, on core: 58/1095, c27_p460bT
# Processing cores, on core: 59/1095, c66_p459bN
# Processing cores, on core: 60/1095, c61_p453aN
# Processing cores, on core: 61/1095, c51_p454aT
# Processing cores, on core: 62/1095, c43_p454aT
# Processing cores, on core: 63/1095, c11_p454aT
# Processing cores, on core: 64/1095, c63_p453aN
# Processing cores, on core: 65/1095, c49_p464bN
# Processing cores, on core: 66/1095, c45_p459aN
# Processing cores, on core: 67/1095, c9_p468aN
# Processing cores, on core: 68/1095, c53_p472aN
# Processing cores, on core: 69/1095, c5_p469bT
# Processing cores, on core: 70/1095, c24_p469aN
# Processing cores, on core: 71/1095, c29_p469bN
# Processing cores, on core: 72/1095, c55_p469cN
# Processing cores, on core: 73/1095, c16_p470bT
# Processing cores, on core: 74/1095, c25_p470bT
# Processing cores, on core: 75/1095, c47_p470bT
# Processing cores, on core: 76/1095, c2_p471aT
# Processing cores, on core: 77/1095, c35_p471aT
# Processing cores, on core: 78/1095, c42_p471aT
# Processing cores, on core: 79/1095, c22_p472aN
# Processing cores, on core: 80/1095, c54_p472bN
# Processing cores, on core: 81/1095, c10_p452aN
# Processing cores, on core: 82/1095, c40_p468aN
# Processing cores, on core: 83/1095, c1_p452aN
# Processing cores, on core: 84/1095, c60_p421aT
# Processing cores, on core: 85/1095, c26_p449aN
# Processing cores, on core: 86/1095, c17_p370aT
# Processing cores, on core: 87/1095, c48_p370aT
# Processing cores, on core: 88/1095, c37_p374aN
# Processing cores, on core: 89/1095, c41_p449aN
# Processing cores, on core: 90/1095, c52_p374bN
# Processing cores, on core: 91/1095, c32_p378aT
# Processing cores, on core: 92/1095, c36_p378aT
# Processing cores, on core: 93/1095, c46_p378aT
# Processing cores, on core: 94/1095, c3_p399aT
# Processing cores, on core: 95/1095, c7_p399bT
# Processing cores, on core: 96/1095, c44_p399aT
# Processing cores, on core: 97/1095, c19_p418aT
# Processing cores, on core: 98/1095, c59_p418aT
# Processing cores, on core: 99/1095, c8_p421aT
# Processing cores, on core: 100/1095, c50_p374aN
# Processing cores, on core: 101/1095, c64_p421aT
# Processing cores, on core: 102/1095, c13_p449bN
# Processing cores, on core: 103/1095, c12_p445eN
# Processing cores, on core: 104/1095, c28_p433aT
# Processing cores, on core: 105/1095, c21_p433aT
# Processing cores, on core: 106/1095, c20_p430aN
# Processing cores, on core: 107/1095, c23_p445bN
# Processing cores, on core: 108/1095, c65_p423aN
# Processing cores, on core: 109/1095, c62_p423aT
# Processing cores, on core: 110/1095, c56_p423aN
# Processing cores, on core: 111/1095, c31_p423aN
# Processing cores, on core: 112/1095, c18_p423aT
# Processing cores, on core: 113/1095, c15_p430aN
# Processing cores, on core: 114/1095, c37_p422aN
# Processing cores, on core: 115/1095, c39_p351bN
# Processing cores, on core: 116/1095, c62_p351aN
# Processing cores, on core: 117/1095, c18_p406bN
# Processing cores, on core: 118/1095, c23_p406aT
# Processing cores, on core: 119/1095, c27_p406aT
# Processing cores, on core: 120/1095, c45_p406aN
# Processing cores, on core: 121/1095, c10_p422bN
# Processing cores, on core: 122/1095, c13_p422aT
# Processing cores, on core: 123/1095, c42_p422bN
# Processing cores, on core: 124/1095, c41_p424aT
# Processing cores, on core: 125/1095, c1_p424aT
# Processing cores, on core: 126/1095, c5_p424aN
# Processing cores, on core: 127/1095, c7_p424aN
# Processing cores, on core: 128/1095, c29_p424aN
# Processing cores, on core: 129/1095, c30_p351aN
# Processing cores, on core: 130/1095, c53_p424aT
# Processing cores, on core: 131/1095, c8_p432aT
# Processing cores, on core: 132/1095, c40_p432bN
# Processing cores, on core: 133/1095, c69_p432bT
# Processing cores, on core: 134/1095, c58_p422aT
# Processing cores, on core: 135/1095, c51_p333aN
# Processing cores, on core: 136/1095, c9_p122bN
# Processing cores, on core: 137/1095, c32_p332aN
# Processing cores, on core: 138/1095, c57_p332bN
# Processing cores, on core: 139/1095, c6_p1aT
# Processing cores, on core: 140/1095, c15_p1bT
# Processing cores, on core: 141/1095, c31_p1bT
# Processing cores, on core: 142/1095, c11_p3aT
# Processing cores, on core: 143/1095, c35_p3bN
# Processing cores, on core: 144/1095, c16_p89bN
# Processing cores, on core: 145/1095, c22_p98bN
# Processing cores, on core: 146/1095, c52_p98bN
# Processing cores, on core: 147/1095, c50_p3bT
# Processing cores, on core: 148/1095, c46_p122aT
# Processing cores, on core: 149/1095, c49_p122aT
# Processing cores, on core: 150/1095, c64_p122aT
# Processing cores, on core: 151/1095, c4_p147aN
# Processing cores, on core: 152/1095, c12_p147aT
# Processing cores, on core: 153/1095, c67_p147aT
# Processing cores, on core: 154/1095, c3_p149bN
# Processing cores, on core: 155/1095, c66_p149aN
# Processing cores, on core: 156/1095, c26_p122bT
# Processing cores, on core: 157/1095, c34_p209aT
# Processing cores, on core: 158/1095, c79_p524bT
# Processing cores, on core: 159/1095, c11_p541aT
# Processing cores, on core: 160/1095, c67_p539aT
# Processing cores, on core: 161/1095, c27_p539aN
# Processing cores, on core: 162/1095, c16_p539aN
# Processing cores, on core: 163/1095, c42_p525aN
# Processing cores, on core: 164/1095, c69_p525aN
# Processing cores, on core: 165/1095, c65_p525bT
# Processing cores, on core: 166/1095, c44_p541aT
# Processing cores, on core: 167/1095, c7_p539aN
# Processing cores, on core: 168/1095, c76_p541aT
# Processing cores, on core: 169/1095, c70_p585aT
# Processing cores, on core: 170/1095, c10_p555bN
# Processing cores, on core: 171/1095, c40_p555bT
# Processing cores, on core: 172/1095, c52_p555aN
# Processing cores, on core: 173/1095, c15_p571bN
# Processing cores, on core: 174/1095, c19_p571aN
# Processing cores, on core: 175/1095, c63_p571bN
# Processing cores, on core: 176/1095, c28_p585aT
# Processing cores, on core: 177/1095, c55_p585aT
# Processing cores, on core: 178/1095, c58_p524aN
# Processing cores, on core: 179/1095, c5_p598aT
# Processing cores, on core: 180/1095, c36_p598aT
# Processing cores, on core: 181/1095, c39_p598aT
# Processing cores, on core: 182/1095, c2_p555bN
# Processing cores, on core: 183/1095, c49_p524bT
# Processing cores, on core: 184/1095, c12_p539aN
# Processing cores, on core: 185/1095, c78_p506bT
# Processing cores, on core: 186/1095, c30_p524bT
# Processing cores, on core: 187/1095, c1_p465bN
# Processing cores, on core: 188/1095, c9_p465aN
# Processing cores, on core: 189/1095, c43_p465aN
# Processing cores, on core: 190/1095, c17_p491aN
# Processing cores, on core: 191/1095, c47_p491aT
# Processing cores, on core: 192/1095, c57_p491aT
# Processing cores, on core: 193/1095, c13_p493aN
# Processing cores, on core: 194/1095, c32_p493aN
# Processing cores, on core: 195/1095, c37_p493bN
# Processing cores, on core: 196/1095, c41_p493aN
# Processing cores, on core: 197/1095, c4_p494aN
# Processing cores, on core: 198/1095, c31_p491bN
# Processing cores, on core: 199/1095, c48_p494aN
# Processing cores, on core: 200/1095, c68_p506bT
# Processing cores, on core: 201/1095, c23_p494aN
# Processing cores, on core: 202/1095, c62_p506bN
# Processing cores, on core: 203/1095, c73_p497bT
# Processing cores, on core: 204/1095, c60_p495bN
# Processing cores, on core: 205/1095, c6_p506bT
# Processing cores, on core: 206/1095, c50_p495bN
# Processing cores, on core: 207/1095, c46_p495aN
# Processing cores, on core: 208/1095, c29_p495bN
# Processing cores, on core: 209/1095, c61_p494aN
# Processing cores, on core: 210/1095, c51_p494aT
# Processing cores, on core: 211/1095, c83_p44bT
# Processing cores, on core: 212/1095, c51_p45aN
# Processing cores, on core: 213/1095, c42_p45bN
# Processing cores, on core: 214/1095, c24_p45bN
# Processing cores, on core: 215/1095, c92_p44bT
# Processing cores, on core: 216/1095, c14_p51bN
# Processing cores, on core: 217/1095, c65_p44aT
# Processing cores, on core: 218/1095, c23_p39bT
# Processing cores, on core: 219/1095, c30_p43aT
# Processing cores, on core: 220/1095, c12_p43aT
# Processing cores, on core: 221/1095, c7_p43bT
# Processing cores, on core: 222/1095, c18_p39aN
# Processing cores, on core: 223/1095, c4_p39bT
# Processing cores, on core: 224/1095, c20_p51bN
# Processing cores, on core: 225/1095, c58_p44aN
# Processing cores, on core: 226/1095, c59_p51bN
# Processing cores, on core: 227/1095, c11_p99bN
# Processing cores, on core: 228/1095, c33_p52cN
# Processing cores, on core: 229/1095, c85_p36bT
# Processing cores, on core: 230/1095, c60_p471bT
# Processing cores, on core: 231/1095, c48_p471bT
# Processing cores, on core: 232/1095, c37_p471aT
# Processing cores, on core: 233/1095, c49_p99bN
# Processing cores, on core: 234/1095, c90_p88aT
# Processing cores, on core: 235/1095, c61_p88aT
# Processing cores, on core: 236/1095, c10_p88aT
# Processing cores, on core: 237/1095, c73_p65bN
# Processing cores, on core: 238/1095, c2_p65aN
# Processing cores, on core: 239/1095, c66_p59bN
# Processing cores, on core: 240/1095, c44_p59aN
# Processing cores, on core: 241/1095, c32_p59bN
# Processing cores, on core: 242/1095, c82_p52aN
# Processing cores, on core: 243/1095, c38_p52bN
# Processing cores, on core: 244/1095, c71_p51aN
# Processing cores, on core: 245/1095, c78_p36bN
# Processing cores, on core: 246/1095, c27_p65bN
# Processing cores, on core: 247/1095, c39_p36aN
# Processing cores, on core: 248/1095, c22_p15aT
# Processing cores, on core: 249/1095, c15_p15aN
# Processing cores, on core: 250/1095, c3_p15aN
# Processing cores, on core: 251/1095, c72_p9aT
# Processing cores, on core: 252/1095, c67_p9aN
# Processing cores, on core: 253/1095, c54_p9cT
# Processing cores, on core: 254/1095, c56_p15bN
# Processing cores, on core: 255/1095, c8_p9aT
# Processing cores, on core: 256/1095, c84_p7aN
# Processing cores, on core: 257/1095, c77_p7bN
# Processing cores, on core: 258/1095, c16_p7bT
# Processing cores, on core: 259/1095, c9_p7bN
# Processing cores, on core: 260/1095, c5_p7aN
# Processing cores, on core: 261/1095, c46_p36aT
# Processing cores, on core: 262/1095, c1_p9aN
# Processing cores, on core: 263/1095, c63_p15bT
# Processing cores, on core: 264/1095, c41_p9aN
# Processing cores, on core: 265/1095, c25_p16aN
# Processing cores, on core: 266/1095, c89_p15aN
# Processing cores, on core: 267/1095, c68_p32aT
# Processing cores, on core: 268/1095, c53_p32aT
# Processing cores, on core: 269/1095, c91_p23bT
# Processing cores, on core: 270/1095, c75_p23aT
# Processing cores, on core: 271/1095, c70_p23aN
# Processing cores, on core: 272/1095, c26_p23aT
# Processing cores, on core: 273/1095, c80_p22bT
# Processing cores, on core: 274/1095, c81_p32aT
# Processing cores, on core: 275/1095, c57_p22aN
# Processing cores, on core: 276/1095, c69_p21bT
# Processing cores, on core: 277/1095, c62_p21bN
# Processing cores, on core: 278/1095, c50_p21aT
# Processing cores, on core: 279/1095, c43_p21aN
# Processing cores, on core: 280/1095, c29_p16aN
# Processing cores, on core: 281/1095, c28_p16bN
# Processing cores, on core: 282/1095, c23_p69aT
# Processing cores, on core: 283/1095, c50_p69bN
# Processing cores, on core: 284/1095, c62_p69bN
# Processing cores, on core: 285/1095, c28_p74aN
# Processing cores, on core: 286/1095, c37_p74aN
# Processing cores, on core: 287/1095, c1_p76cN
# Processing cores, on core: 288/1095, c60_p76bT
# Processing cores, on core: 289/1095, c13_p77aN
# Processing cores, on core: 290/1095, c45_p77aN
# Processing cores, on core: 291/1095, c63_p87bT
# Processing cores, on core: 292/1095, c31_p87bT
# Processing cores, on core: 293/1095, c20_p69aT
# Processing cores, on core: 294/1095, c65_p87aT
# Processing cores, on core: 295/1095, c21_p90aT
# Processing cores, on core: 296/1095, c46_p90aN
# Processing cores, on core: 297/1095, c52_p90aT
# Processing cores, on core: 298/1095, c35_p108aN
# Processing cores, on core: 299/1095, c40_p108bT
# Processing cores, on core: 300/1095, c2_p87bN
# Processing cores, on core: 301/1095, c67_p67aN
# Processing cores, on core: 302/1095, c64_p90aN
# Processing cores, on core: 303/1095, c26_p67aT
# Processing cores, on core: 304/1095, c57_p67aT
# Processing cores, on core: 305/1095, c7_p10bN
# Processing cores, on core: 306/1095, c10_p18aT
# Processing cores, on core: 307/1095, c12_p18aT
# Processing cores, on core: 308/1095, c36_p18aN
# Processing cores, on core: 309/1095, c19_p31cT
# Processing cores, on core: 310/1095, c27_p31dT
# Processing cores, on core: 311/1095, c44_p31bN
# Processing cores, on core: 312/1095, c61_p31dT
# Processing cores, on core: 313/1095, c14_p18bN
# Processing cores, on core: 314/1095, c51_p47aT
# Processing cores, on core: 315/1095, c5_p48aT
# Processing cores, on core: 316/1095, c15_p48bN
# Processing cores, on core: 317/1095, c22_p48bT
# Processing cores, on core: 318/1095, c39_p48bT
# Processing cores, on core: 319/1095, c54_p48aN
# Processing cores, on core: 320/1095, c70_p48aN
# Processing cores, on core: 321/1095, c16_p67aN
# Processing cores, on core: 322/1095, c25_p67aT
# Processing cores, on core: 323/1095, c42_p47aN
# Processing cores, on core: 324/1095, c74_p44bN
# Processing cores, on core: 325/1095, c60_p44aT
# Processing cores, on core: 326/1095, c53_p44aN
# Processing cores, on core: 327/1095, c28_p43aT
# Processing cores, on core: 328/1095, c10_p43aT
# Processing cores, on core: 329/1095, c42_p36aT
# Processing cores, on core: 330/1095, c18_p39aN
# Processing cores, on core: 331/1095, c5_p39bT
# Processing cores, on core: 332/1095, c86_p36aN
# Processing cores, on core: 333/1095, c81_p44bT
# Processing cores, on core: 334/1095, c21_p39bT
# Processing cores, on core: 335/1095, c22_p45bN
# Processing cores, on core: 336/1095, c69_p65bN
# Processing cores, on core: 337/1095, c67_p51aN
# Processing cores, on core: 338/1095, c80_p52aN
# Processing cores, on core: 339/1095, c87_p52bT
# Processing cores, on core: 340/1095, c31_p59bN
# Processing cores, on core: 341/1095, c40_p59aN
# Processing cores, on core: 342/1095, c62_p59bN
# Processing cores, on core: 343/1095, c2_p65aN
# Processing cores, on core: 344/1095, c25_p65bN
# Processing cores, on core: 345/1095, c3_p36aT
# Processing cores, on core: 346/1095, c8_p88aT
# Processing cores, on core: 347/1095, c56_p88aT
# Processing cores, on core: 348/1095, c88_p88aT
# Processing cores, on core: 349/1095, c45_p471bT
# Processing cores, on core: 350/1095, c54_p51bN
# Processing cores, on core: 351/1095, c79_p32aT
# Processing cores, on core: 352/1095, c91_p23bT
# Processing cores, on core: 353/1095, c49_p32aT
# Processing cores, on core: 354/1095, c7_p7bN
# Processing cores, on core: 355/1095, c12_p7aN
# Processing cores, on core: 356/1095, c14_p7bT
# Processing cores, on core: 357/1095, c76_p7bN
# Processing cores, on core: 358/1095, c64_p32aT
# Processing cores, on core: 359/1095, c38_p9aN
# Processing cores, on core: 360/1095, c51_p9cT
# Processing cores, on core: 361/1095, c68_p9aT
# Processing cores, on core: 362/1095, c4_p15aN
# Processing cores, on core: 363/1095, c16_p15aN
# Processing cores, on core: 364/1095, c23_p16aN
# Processing cores, on core: 365/1095, c27_p16aN
# Processing cores, on core: 366/1095, c11_p9aT
# Processing cores, on core: 367/1095, c39_p21aT
# Processing cores, on core: 368/1095, c33_p16aT
# Processing cores, on core: 369/1095, c84_p23bN
# Processing cores, on core: 370/1095, c73_p23aT
# Processing cores, on core: 371/1095, c17_p23aN
# Processing cores, on core: 372/1095, c71_p22bN
# Processing cores, on core: 373/1095, c66_p23aT
# Processing cores, on core: 374/1095, c52_p22aN
# Processing cores, on core: 375/1095, c65_p21bT
# Processing cores, on core: 376/1095, c57_p21bN
# Processing cores, on core: 377/1095, c46_p21aT
# Processing cores, on core: 378/1095, c44_p21aN
# Processing cores, on core: 379/1095, c59_p22aN
# Processing cores, on core: 380/1095, c16_p543aT
# Processing cores, on core: 381/1095, c43_p536aN
# Processing cores, on core: 382/1095, c52_p536aN
# Processing cores, on core: 383/1095, c13_p538aN
# Processing cores, on core: 384/1095, c33_p538aN
# Processing cores, on core: 385/1095, c37_p538aT
# Processing cores, on core: 386/1095, c32_p543aT
# Processing cores, on core: 387/1095, c25_p600bT
# Processing cores, on core: 388/1095, c4_p552aT
# Processing cores, on core: 389/1095, c40_p552aT
# Processing cores, on core: 390/1095, c5_p600bT
# Processing cores, on core: 391/1095, c20_p600bN
# Processing cores, on core: 392/1095, c21_p600bN
# Processing cores, on core: 393/1095, c38_p600bT
# Processing cores, on core: 394/1095, c45_p600bN
# Processing cores, on core: 395/1095, c42_p543aT
# Processing cores, on core: 396/1095, c49_p533dN
# Processing cores, on core: 397/1095, c30_p533dT
# Processing cores, on core: 398/1095, c44_p533dT
# Processing cores, on core: 399/1095, c47_p533dT
# Processing cores, on core: 400/1095, c1_p64aN
# Processing cores, on core: 401/1095, c31_p64aN
# Processing cores, on core: 402/1095, c46_p64aN
# Processing cores, on core: 403/1095, c11_p484bN
# Processing cores, on core: 404/1095, c18_p484bN
# Processing cores, on core: 405/1095, c51_p484bN
# Processing cores, on core: 406/1095, c6_p64aN
# Processing cores, on core: 407/1095, c15_p505bT
# Processing cores, on core: 408/1095, c22_p505cT
# Processing cores, on core: 409/1095, c53_p505cT
# Processing cores, on core: 410/1095, c7_p524cT
# Processing cores, on core: 411/1095, c23_p524cT
# Processing cores, on core: 412/1095, c50_p524cT
# Processing cores, on core: 413/1095, c2_p533dT
# Processing cores, on core: 414/1095, c3_p505cN
# Processing cores, on core: 415/1095, c44_p567aT
# Processing cores, on core: 416/1095, c18_p567aT
# Processing cores, on core: 417/1095, c68_p563bN
# Processing cores, on core: 418/1095, c53_p563bN
# Processing cores, on core: 419/1095, c42_p563bN
# Processing cores, on core: 420/1095, c19_p561bT
# Processing cores, on core: 421/1095, c32_p561bN
# Processing cores, on core: 422/1095, c23_p561aN
# Processing cores, on core: 423/1095, c15_p561aN
# Processing cores, on core: 424/1095, c28_p568aT
# Processing cores, on core: 425/1095, c4_p563aN
# Processing cores, on core: 426/1095, c54_p568aT
# Processing cores, on core: 427/1095, c7_p615bN
# Processing cores, on core: 428/1095, c8_p609aT
# Processing cores, on core: 429/1095, c34_p609aT
# Processing cores, on core: 430/1095, c40_p609aT
# Processing cores, on core: 431/1095, c5_p613aN
# Processing cores, on core: 432/1095, c25_p613bN
# Processing cores, on core: 433/1095, c36_p613aN
# Processing cores, on core: 434/1095, c6_p615aT
# Processing cores, on core: 435/1095, c10_p561aN
# Processing cores, on core: 436/1095, c52_p615aN
# Processing cores, on core: 437/1095, c55_p615dN
# Processing cores, on core: 438/1095, c20_p617bN
# Processing cores, on core: 439/1095, c24_p617bT
# Processing cores, on core: 440/1095, c56_p568aT
# Processing cores, on core: 441/1095, c37_p559bN
# Processing cores, on core: 442/1095, c64_p617aN
# Processing cores, on core: 443/1095, c11_p559bN
# Processing cores, on core: 444/1095, c41_p516aT
# Processing cores, on core: 445/1095, c35_p559bN
# Processing cores, on core: 446/1095, c57_p516aN
# Processing cores, on core: 447/1095, c63_p516aT
# Processing cores, on core: 448/1095, c65_p516aT
# Processing cores, on core: 449/1095, c22_p519aT
# Processing cores, on core: 450/1095, c61_p519aT
# Processing cores, on core: 451/1095, c67_p519aT
# Processing cores, on core: 452/1095, c38_p523bN
# Processing cores, on core: 453/1095, c49_p523bT
# Processing cores, on core: 454/1095, c60_p523cN
# Processing cores, on core: 455/1095, c33_p538aN
# Processing cores, on core: 456/1095, c39_p538aN
# Processing cores, on core: 457/1095, c43_p516bN
# Processing cores, on core: 458/1095, c58_p538bT
# Processing cores, on core: 459/1095, c48_p538bN
# Processing cores, on core: 460/1095, c14_p556bT
# Processing cores, on core: 461/1095, c47_p551aN
# Processing cores, on core: 462/1095, c26_p551bN
# Processing cores, on core: 463/1095, c16_p551aN
# Processing cores, on core: 464/1095, c66_p556bT
# Processing cores, on core: 465/1095, c21_p540aN
# Processing cores, on core: 466/1095, c13_p540bT
# Processing cores, on core: 467/1095, c12_p540bN
# Processing cores, on core: 468/1095, c9_p540bN
# Processing cores, on core: 469/1095, c62_p538aN
# Processing cores, on core: 470/1095, c27_p540aT
# Processing cores, on core: 471/1095, c33_p75aT
# Processing cores, on core: 472/1095, c9_p75bN
# Processing cores, on core: 473/1095, c58_p70aN
# Processing cores, on core: 474/1095, c52_p70aT
# Processing cores, on core: 475/1095, c12_p70aN
# Processing cores, on core: 476/1095, c3_p70bN
# Processing cores, on core: 477/1095, c63_p54aN
# Processing cores, on core: 478/1095, c56_p54bT
# Processing cores, on core: 479/1095, c41_p75aT
# Processing cores, on core: 480/1095, c38_p70bT
# Processing cores, on core: 481/1095, c5_p78bN
# Processing cores, on core: 482/1095, c59_p79aN
# Processing cores, on core: 483/1095, c35_p78bN
# Processing cores, on core: 484/1095, c71_p78aN
# Processing cores, on core: 485/1095, c30_p79bN
# Processing cores, on core: 486/1095, c49_p79bT
# Processing cores, on core: 487/1095, c2_p85aT
# Processing cores, on core: 488/1095, c18_p85bT
# Processing cores, on core: 489/1095, c53_p85bT
# Processing cores, on core: 490/1095, c62_p85bN
# Processing cores, on core: 491/1095, c44_p107bT
# Processing cores, on core: 492/1095, c66_p107aN
# Processing cores, on core: 493/1095, c28_p78bT
# Processing cores, on core: 494/1095, c23_p54bT
# Processing cores, on core: 495/1095, c57_p41aT
# Processing cores, on core: 496/1095, c60_p41bN
# Processing cores, on core: 497/1095, c11_p54bN
# Processing cores, on core: 498/1095, c24_p14aN
# Processing cores, on core: 499/1095, c48_p14bT
# Processing cores, on core: 500/1095, c13_p25aN
# Processing cores, on core: 501/1095, c20_p25aT
# Processing cores, on core: 502/1095, c47_p25bT
# Processing cores, on core: 503/1095, c27_p27aN
# Processing cores, on core: 504/1095, c39_p27aN
# Processing cores, on core: 505/1095, c70_p27bN
# Processing cores, on core: 506/1095, c4_p29bN
# Processing cores, on core: 507/1095, c15_p29bT
# Processing cores, on core: 508/1095, c55_p25aT
# Processing cores, on core: 509/1095, c45_p29aT
# Processing cores, on core: 510/1095, c32_p29bT
# Processing cores, on core: 511/1095, c31_p41bN
# Processing cores, on core: 512/1095, c10_p41bT
# Processing cores, on core: 513/1095, c6_p41bT
# Processing cores, on core: 514/1095, c50_p38bN
# Processing cores, on core: 515/1095, c51_p41aN
# Processing cores, on core: 516/1095, c37_p38bT
# Processing cores, on core: 517/1095, c17_p38bT
# Processing cores, on core: 518/1095, c61_p29bN
# Processing cores, on core: 519/1095, c42_p38aN
# Processing cores, on core: 520/1095, c54_p510aN
# Processing cores, on core: 521/1095, c41_p489aT
# Processing cores, on core: 522/1095, c55_p489bT
# Processing cores, on core: 523/1095, c18_p494bN
# Processing cores, on core: 524/1095, c37_p494cN
# Processing cores, on core: 525/1095, c9_p496bT
# Processing cores, on core: 526/1095, c45_p496bT
# Processing cores, on core: 527/1095, c47_p496aN
# Processing cores, on core: 528/1095, c29_p510aN
# Processing cores, on core: 529/1095, c38_p510aN
# Processing cores, on core: 530/1095, c4_p532bN
# Processing cores, on core: 531/1095, c36_p489aN
# Processing cores, on core: 532/1095, c26_p532bN
# Processing cores, on core: 533/1095, c52_p550bT
# Processing cores, on core: 534/1095, c60_p550bT
# Processing cores, on core: 535/1095, c42_p589aT
# Processing cores, on core: 536/1095, c14_p603bN
# Processing cores, on core: 537/1095, c20_p603bT
# Processing cores, on core: 538/1095, c23_p603bT
# Processing cores, on core: 539/1095, c27_p603aN
# Processing cores, on core: 540/1095, c33_p603bT
# Processing cores, on core: 541/1095, c46_p603aN
# Processing cores, on core: 542/1095, c15_p532bN
# Processing cores, on core: 543/1095, c17_p489bT
# Processing cores, on core: 544/1095, c10_p494bN
# Processing cores, on core: 545/1095, c40_p488bN
# Processing cores, on core: 546/1095, c6_p473bT
# Processing cores, on core: 547/1095, c43_p473bN
# Processing cores, on core: 548/1095, c44_p473aT
# Processing cores, on core: 549/1095, c51_p473bN
# Processing cores, on core: 550/1095, c3_p481bN
# Processing cores, on core: 551/1095, c12_p481bN
# Processing cores, on core: 552/1095, c57_p481bN
# Processing cores, on core: 553/1095, c63_p481bN
# Processing cores, on core: 554/1095, c62_p489bN
# Processing cores, on core: 555/1095, c25_p482aN
# Processing cores, on core: 556/1095, c30_p482cN
# Processing cores, on core: 557/1095, c22_p474aT
# Processing cores, on core: 558/1095, c50_p482aT
# Processing cores, on core: 559/1095, c31_p482aT
# Processing cores, on core: 560/1095, c28_p488aN
# Processing cores, on core: 561/1095, c24_p488aT
# Processing cores, on core: 562/1095, c1_p488aN
# Processing cores, on core: 563/1095, c49_p488aN
# Processing cores, on core: 564/1095, c21_p486aT
# Processing cores, on core: 565/1095, c19_p486aT
# Processing cores, on core: 566/1095, c64_p482bT
# Processing cores, on core: 567/1095, c58_p482bT
# Processing cores, on core: 568/1095, c35_p486aT
# Processing cores, on core: 569/1095, c17_p461aT
# Processing cores, on core: 570/1095, c38_p468aN
# Processing cores, on core: 571/1095, c34_p461bT
# Processing cores, on core: 572/1095, c39_p461aT
# Processing cores, on core: 573/1095, c13_p468aN
# Processing cores, on core: 574/1095, c25_p469aN
# Processing cores, on core: 575/1095, c48_p472aN
# Processing cores, on core: 576/1095, c26_p470bT
# Processing cores, on core: 577/1095, c44_p470bT
# Processing cores, on core: 578/1095, c9_p471aT
# Processing cores, on core: 579/1095, c40_p471aT
# Processing cores, on core: 580/1095, c49_p472bN
# Processing cores, on core: 581/1095, c51_p460bT
# Processing cores, on core: 582/1095, c50_p469cN
# Processing cores, on core: 583/1095, c14_p454aT
# Processing cores, on core: 584/1095, c29_p433aT
# Processing cores, on core: 585/1095, c27_p449aN
# Processing cores, on core: 586/1095, c54_p453aN
# Processing cores, on core: 587/1095, c32_p378aT
# Processing cores, on core: 588/1095, c37_p378aT
# Processing cores, on core: 589/1095, c11_p399bT
# Processing cores, on core: 590/1095, c12_p421aT
# Processing cores, on core: 591/1095, c57_p421aT
# Processing cores, on core: 592/1095, c20_p423aT
# Processing cores, on core: 593/1095, c36_p374aN
# Processing cores, on core: 594/1095, c18_p430aN
# Processing cores, on core: 595/1095, c23_p433aT
# Processing cores, on core: 596/1095, c15_p445eN
# Processing cores, on core: 597/1095, c24_p445bN
# Processing cores, on core: 598/1095, c16_p449bN
# Processing cores, on core: 599/1095, c31_p423aN
# Processing cores, on core: 600/1095, c59_p208bT
# Processing cores, on core: 601/1095, c79_p217aT
# Processing cores, on core: 602/1095, c73_p223bN
# Processing cores, on core: 603/1095, c36_p224aN
# Processing cores, on core: 604/1095, c86_p224aN
# Processing cores, on core: 605/1095, c90_p224sT
# Processing cores, on core: 606/1095, c55_p226aT
# Processing cores, on core: 607/1095, c25_p226aT
# Processing cores, on core: 608/1095, c62_p337sT
# Processing cores, on core: 609/1095, c87_p337aN
# Processing cores, on core: 610/1095, c94_p405aN
# Processing cores, on core: 611/1095, c6_p415aN
# Processing cores, on core: 612/1095, c81_p150bN
# Processing cores, on core: 613/1095, c99_p224bN
# Processing cores, on core: 614/1095, c61_p150bN
# Processing cores, on core: 615/1095, c32_p124bT
# Processing cores, on core: 616/1095, c7_p146cN
# Processing cores, on core: 617/1095, c9_p146aN
# Processing cores, on core: 618/1095, c2_p61aT
# Processing cores, on core: 619/1095, c53_p86aN
# Processing cores, on core: 620/1095, c85_p108bN
# Processing cores, on core: 621/1095, c57_p119bN
# Processing cores, on core: 622/1095, c63_p119aN
# Processing cores, on core: 623/1095, c31_p112bT
# Processing cores, on core: 624/1095, c83_p124aT
# Processing cores, on core: 625/1095, c34_p143aN
# Processing cores, on core: 626/1095, c45_p144aT
# Processing cores, on core: 627/1095, c84_p144aT
# Processing cores, on core: 628/1095, c4_p146bN
# Processing cores, on core: 629/1095, c13_p123aN
# Processing cores, on core: 630/1095, c83_p224aN
# Processing cores, on core: 631/1095, c79_p217bT
# Processing cores, on core: 632/1095, c43_p224aT
# Processing cores, on core: 633/1095, c37_p224aN
# Processing cores, on core: 634/1095, c7_p224aT
# Processing cores, on core: 635/1095, c74_p223bN
# Processing cores, on core: 636/1095, c26_p223aT
# Processing cores, on core: 637/1095, c78_p217aT
# Processing cores, on core: 638/1095, c49_p208aT
# Processing cores, on core: 639/1095, c71_p217aN
# Processing cores, on core: 640/1095, c8_p217bT
# Processing cores, on core: 641/1095, c80_p208bT
# Processing cores, on core: 642/1095, c61_p208bT
# Processing cores, on core: 643/1095, c89_p224sT
# Processing cores, on core: 644/1095, c51_p190aT
# Processing cores, on core: 645/1095, c88_p150aN
# Processing cores, on core: 646/1095, c81_p150bN
# Processing cores, on core: 647/1095, c72_p217bN
# Processing cores, on core: 648/1095, c24_p226aT
# Processing cores, on core: 649/1095, c68_p401bN
# Processing cores, on core: 650/1095, c95_p226aT
# Processing cores, on core: 651/1095, c17_p146bT
# Processing cores, on core: 652/1095, c97_p415aN
# Processing cores, on core: 653/1095, c87_p415sT
# Processing cores, on core: 654/1095, c36_p415aN
# Processing cores, on core: 655/1095, c12_p415aT
# Processing cores, on core: 656/1095, c4_p415aN
# Processing cores, on core: 657/1095, c93_p405aN
# Processing cores, on core: 658/1095, c86_p405bN
# Processing cores, on core: 659/1095, c77_p405sN
# Processing cores, on core: 660/1095, c70_p405aN
# Processing cores, on core: 661/1095, c11_p405sN
# Processing cores, on core: 662/1095, c2_p405aN
# Processing cores, on core: 663/1095, c75_p401bT
# Processing cores, on core: 664/1095, c19_p401aN
# Processing cores, on core: 665/1095, c92_p337aT
# Processing cores, on core: 666/1095, c54_p337sT
# Processing cores, on core: 667/1095, c47_p337bN
# Processing cores, on core: 668/1095, c57_p226aT
# Processing cores, on core: 669/1095, c15_p146cT
# Processing cores, on core: 670/1095, c100_p190bT
# Processing cores, on core: 671/1095, c9_p146aN
# Processing cores, on core: 672/1095, c38_p112bN
# Processing cores, on core: 673/1095, c34_p112aT
# Processing cores, on core: 674/1095, c30_p112bT
# Processing cores, on core: 675/1095, c25_p112aN
# Processing cores, on core: 676/1095, c22_p112bT
# Processing cores, on core: 677/1095, c85_p108bN
# Processing cores, on core: 678/1095, c1_p108aN
# Processing cores, on core: 679/1095, c96_p86cT
# Processing cores, on core: 680/1095, c90_p86aN
# Processing cores, on core: 681/1095, c55_p86aN
# Processing cores, on core: 682/1095, c48_p86aN
# Processing cores, on core: 683/1095, c39_p86cN
# Processing cores, on core: 684/1095, c58_p61aT
# Processing cores, on core: 685/1095, c53_p61aT
# Processing cores, on core: 686/1095, c94_p33aN
# Processing cores, on core: 687/1095, c33_p33bN
# Processing cores, on core: 688/1095, c13_p146aT
# Processing cores, on core: 689/1095, c45_p112aT
# Processing cores, on core: 690/1095, c21_p119bT
# Processing cores, on core: 691/1095, c50_p33aN
# Processing cores, on core: 692/1095, c60_p119bN
# Processing cores, on core: 693/1095, c28_p119bT
# Processing cores, on core: 694/1095, c41_p144aT
# Processing cores, on core: 695/1095, c14_p144bT
# Processing cores, on core: 696/1095, c52_p143bN
# Processing cores, on core: 697/1095, c40_p143bN
# Processing cores, on core: 698/1095, c5_p146bN
# Processing cores, on core: 699/1095, c73_p142aT
# Processing cores, on core: 700/1095, c42_p142sT
# Processing cores, on core: 701/1095, c35_p143aN
# Processing cores, on core: 702/1095, c66_p124aT
# Processing cores, on core: 703/1095, c59_p124aN
# Processing cores, on core: 704/1095, c23_p124bN
# Processing cores, on core: 705/1095, c64_p123aN
# Processing cores, on core: 706/1095, c16_p123bN
# Processing cores, on core: 707/1095, c10_p123aN
# Processing cores, on core: 708/1095, c67_p119bT
# Processing cores, on core: 709/1095, c62_p119aN
# Processing cores, on core: 710/1095, c82_p124aN
# Processing cores, on core: 711/1095, c50_p45aN
# Processing cores, on core: 712/1095, c41_p45bN
# Processing cores, on core: 713/1095, c23_p45bN
# Processing cores, on core: 714/1095, c91_p44bT
# Processing cores, on core: 715/1095, c73_p44bN
# Processing cores, on core: 716/1095, c64_p44aT
# Processing cores, on core: 717/1095, c56_p44aN
# Processing cores, on core: 718/1095, c88_p36aN
# Processing cores, on core: 719/1095, c12_p43aT
# Processing cores, on core: 720/1095, c7_p43bT
# Processing cores, on core: 721/1095, c22_p39bT
# Processing cores, on core: 722/1095, c18_p39aN
# Processing cores, on core: 723/1095, c5_p39bT
# Processing cores, on core: 724/1095, c14_p51bN
# Processing cores, on core: 725/1095, c79_p36bN
# Processing cores, on core: 726/1095, c29_p43aT
# Processing cores, on core: 727/1095, c20_p51bN
# Processing cores, on core: 728/1095, c27_p65bN
# Processing cores, on core: 729/1095, c70_p51aN
# Processing cores, on core: 730/1095, c59_p471bT
# Processing cores, on core: 731/1095, c43_p36aT
# Processing cores, on core: 732/1095, c48_p471bT
# Processing cores, on core: 733/1095, c36_p471aT
# Processing cores, on core: 734/1095, c49_p99bN
# Processing cores, on core: 735/1095, c11_p99bN
# Processing cores, on core: 736/1095, c90_p88aT
# Processing cores, on core: 737/1095, c58_p51bN
# Processing cores, on core: 738/1095, c60_p88aT
# Processing cores, on core: 739/1095, c72_p65bN
# Processing cores, on core: 740/1095, c2_p65aN
# Processing cores, on core: 741/1095, c66_p59bN
# Processing cores, on core: 742/1095, c34_p59bN
# Processing cores, on core: 743/1095, c83_p52aN
# Processing cores, on core: 744/1095, c37_p52bN
# Processing cores, on core: 745/1095, c35_p52cN
# Processing cores, on core: 746/1095, c10_p88aT
# Processing cores, on core: 747/1095, c38_p36aN
# Processing cores, on core: 748/1095, c74_p22bN
# Processing cores, on core: 749/1095, c67_p32aT
# Processing cores, on core: 750/1095, c89_p15aN
# Processing cores, on core: 751/1095, c55_p15bN
# Processing cores, on core: 752/1095, c19_p15aN
# Processing cores, on core: 753/1095, c4_p15aN
# Processing cores, on core: 754/1095, c71_p9aT
# Processing cores, on core: 755/1095, c65_p9aN
# Processing cores, on core: 756/1095, c54_p9cT
# Processing cores, on core: 757/1095, c40_p9aN
# Processing cores, on core: 758/1095, c3_p36aT
# Processing cores, on core: 759/1095, c1_p9aN
# Processing cores, on core: 760/1095, c84_p7aT
# Processing cores, on core: 761/1095, c77_p7bN
# Processing cores, on core: 762/1095, c15_p7bT
# Processing cores, on core: 763/1095, c13_p7aN
# Processing cores, on core: 764/1095, c6_p7aN
# Processing cores, on core: 765/1095, c24_p16aN
# Processing cores, on core: 766/1095, c28_p16bN
# Processing cores, on core: 767/1095, c9_p9aT
# Processing cores, on core: 768/1095, c45_p21aN
# Processing cores, on core: 769/1095, c33_p16aN
# Processing cores, on core: 770/1095, c52_p32aT
# Processing cores, on core: 771/1095, c92_p23bT
# Processing cores, on core: 772/1095, c75_p23aT
# Processing cores, on core: 773/1095, c69_p23aN
# Processing cores, on core: 774/1095, c17_p23aN
# Processing cores, on core: 775/1095, c81_p22bT
# Processing cores, on core: 776/1095, c86_p23bN
# Processing cores, on core: 777/1095, c57_p22aN
# Processing cores, on core: 778/1095, c39_p22bN
# Processing cores, on core: 779/1095, c32_p22aN
# Processing cores, on core: 780/1095, c68_p21bT
# Processing cores, on core: 781/1095, c61_p21bN
# Processing cores, on core: 782/1095, c51_p21aT
# Processing cores, on core: 783/1095, c63_p22aT
# Processing cores, on core: 784/1095, c47_p21aN
# Processing cores, on core: 785/1095, c29_p510aN
# Processing cores, on core: 786/1095, c56_p496bN
# Processing cores, on core: 787/1095, c46_p496bT
# Processing cores, on core: 788/1095, c8_p496bT
# Processing cores, on core: 789/1095, c54_p489bT
# Processing cores, on core: 790/1095, c10_p494bT
# Processing cores, on core: 791/1095, c40_p489bN
# Processing cores, on core: 792/1095, c55_p510aN
# Processing cores, on core: 793/1095, c35_p494bT
# Processing cores, on core: 794/1095, c4_p532bN
# Processing cores, on core: 795/1095, c23_p603bT
# Processing cores, on core: 796/1095, c26_p532bN
# Processing cores, on core: 797/1095, c32_p550bT
# Processing cores, on core: 798/1095, c61_p550bT
# Processing cores, on core: 799/1095, c42_p589aT
# Processing cores, on core: 808/1095, c28_p488aN
# Processing cores, on core: 809/1095, c41_p488bN
# Processing cores, on core: 810/1095, c9_p467aT
# Processing cores, on core: 811/1095, c33_p467cT
# Processing cores, on core: 812/1095, c62_p467bT
# Processing cores, on core: 813/1095, c6_p473bT
# Processing cores, on core: 814/1095, c45_p473aT
# Processing cores, on core: 815/1095, c48_p473aT
# Processing cores, on core: 816/1095, c51_p473bN
# Processing cores, on core: 817/1095, c2_p474aT
# Processing cores, on core: 818/1095, c22_p474aT
# Processing cores, on core: 819/1095, c44_p473bN
# Processing cores, on core: 820/1095, c12_p481bN
# Processing cores, on core: 821/1095, c16_p481aN
# Processing cores, on core: 822/1095, c31_p482aT
# Processing cores, on core: 823/1095, c58_p482bN
# Processing cores, on core: 824/1095, c11_p486cN
# Processing cores, on core: 825/1095, c19_p486aT
# Processing cores, on core: 826/1095, c21_p486aT
# Processing cores, on core: 827/1095, c36_p486aT
# Processing cores, on core: 828/1095, c1_p488aN
# Processing cores, on core: 829/1095, c24_p488aN
# Processing cores, on core: 830/1095, c3_p481bN
# Processing cores, on core: 831/1095, c60_p568aT
# Processing cores, on core: 832/1095, c58_p568aT
# Processing cores, on core: 833/1095, c32_p568aT
# Processing cores, on core: 834/1095, c48_p567aT
# Processing cores, on core: 835/1095, c3_p567aT
# Processing cores, on core: 836/1095, c1_p563aT
# Processing cores, on core: 837/1095, c56_p563bN
# Processing cores, on core: 838/1095, c46_p563bN
# Processing cores, on core: 839/1095, c35_p563bT
# Processing cores, on core: 840/1095, c7_p563aN
# Processing cores, on core: 841/1095, c11_p609aT
# Processing cores, on core: 842/1095, c71_p563bN
# Processing cores, on core: 843/1095, c38_p609aT
# Processing cores, on core: 844/1095, c33_p617aN
# Processing cores, on core: 845/1095, c8_p613aN
# Processing cores, on core: 846/1095, c39_p613aN
# Processing cores, on core: 847/1095, c6_p615aT
# Processing cores, on core: 848/1095, c10_p615bN
# Processing cores, on core: 849/1095, c50_p615aT
# Processing cores, on core: 850/1095, c57_p615aN
# Processing cores, on core: 851/1095, c59_p615dN
# Processing cores, on core: 852/1095, c5_p617aT
# Processing cores, on core: 853/1095, c24_p617bN
# Processing cores, on core: 854/1095, c28_p617bN
# Processing cores, on core: 855/1095, c36_p561bN
# Processing cores, on core: 856/1095, c62_p617aN
# Processing cores, on core: 857/1095, c68_p617aN
# Processing cores, on core: 858/1095, c44_p609aT
# Processing cores, on core: 859/1095, c34_p561aT
# Processing cores, on core: 860/1095, c29_p613bN
# Processing cores, on core: 861/1095, c19_p561aN
# Processing cores, on core: 862/1095, c4_p516aN
# Processing cores, on core: 863/1095, c45_p516aT
# Processing cores, on core: 864/1095, c67_p516aT
# Processing cores, on core: 865/1095, c26_p519aT
# Processing cores, on core: 866/1095, c65_p519aT
# Processing cores, on core: 867/1095, c72_p519aT
# Processing cores, on core: 868/1095, c2_p523aT
# Processing cores, on core: 869/1095, c42_p523bN
# Processing cores, on core: 870/1095, c53_p523bT
# Processing cores, on core: 871/1095, c55_p523aT
# Processing cores, on core: 872/1095, c64_p523cT
# Processing cores, on core: 873/1095, c37_p538aN
# Processing cores, on core: 874/1095, c43_p538aN
# Processing cores, on core: 875/1095, c49_p523aN
# Processing cores, on core: 876/1095, c63_p538bN
# Processing cores, on core: 877/1095, c52_p538bN
# Processing cores, on core: 878/1095, c41_p559bN
# Processing cores, on core: 879/1095, c40_p559bN
# Processing cores, on core: 880/1095, c15_p559bN
# Processing cores, on core: 881/1095, c18_p556bT
# Processing cores, on core: 882/1095, c14_p556bT
# Processing cores, on core: 883/1095, c13_p561aT
# Processing cores, on core: 884/1095, c20_p551aN
# Processing cores, on core: 885/1095, c30_p551bN
# Processing cores, on core: 886/1095, c12_p540bN
# Processing cores, on core: 887/1095, c22_p561bT
# Processing cores, on core: 888/1095, c31_p540aT
# Processing cores, on core: 889/1095, c16_p540bN
# Processing cores, on core: 890/1095, c7_p607bT
# Processing cores, on core: 891/1095, c47_p545aT
# Processing cores, on core: 892/1095, c12_p545aT
# Processing cores, on core: 893/1095, c10_p545aT
# Processing cores, on core: 894/1095, c4_p478eT
# Processing cores, on core: 895/1095, c13_p504bN
# Processing cores, on core: 896/1095, c11_p504bT
# Processing cores, on core: 897/1095, c3_p504bT
# Processing cores, on core: 898/1095, c42_p490aT
# Processing cores, on core: 899/1095, c35_p478eT
# Processing cores, on core: 900/1095, c18_p478eT
# Processing cores, on core: 901/1095, c15_p478eN
# Processing cores, on core: 902/1095, c34_p504bT
# Processing cores, on core: 903/1095, c21_p416aT
# Processing cores, on core: 904/1095, c6_p416aT
# Processing cores, on core: 905/1095, c9_p24bN
# Processing cores, on core: 906/1095, c19_p24bN
# Processing cores, on core: 907/1095, c40_p113aN
# Processing cores, on core: 908/1095, c8_p416aT
# Processing cores, on core: 909/1095, c46_p113aT
# Processing cores, on core: 910/1095, c25_p148aT
# Processing cores, on core: 911/1095, c41_p113aN
# Processing cores, on core: 912/1095, c39_p148aT
# Processing cores, on core: 913/1095, c22_p349aT
# Processing cores, on core: 914/1095, c29_p349aT
# Processing cores, on core: 915/1095, c37_p415cT
# Processing cores, on core: 916/1095, c44_p415cT
# Processing cores, on core: 917/1095, c28_p148aT
# Processing cores, on core: 918/1095, c36_p224aN
# Processing cores, on core: 919/1095, c5_p224aT
# Processing cores, on core: 920/1095, c74_p217bT
# Processing cores, on core: 921/1095, c75_p208bT
# Processing cores, on core: 922/1095, c48_p208aT
# Processing cores, on core: 923/1095, c7_p146cN
# Processing cores, on core: 924/1095, c18_p190aT
# Processing cores, on core: 925/1095, c76_p150bN
# Processing cores, on core: 926/1095, c17_p146bT
# Processing cores, on core: 927/1095, c92_p415aN
# Processing cores, on core: 928/1095, c9_p146aN
# Processing cores, on core: 929/1095, c79_p224aN
# Processing cores, on core: 930/1095, c49_p190aT
# Processing cores, on core: 931/1095, c95_p224bN
# Processing cores, on core: 932/1095, c66_p401bN
# Processing cores, on core: 933/1095, c56_p226aT
# Processing cores, on core: 934/1095, c51_p337sT
# Processing cores, on core: 935/1095, c61_p337sT
# Processing cores, on core: 936/1095, c82_p337aT
# Processing cores, on core: 937/1095, c19_p401aN
# Processing cores, on core: 938/1095, c71_p401bT
# Processing cores, on core: 939/1095, c3_p405aN
# Processing cores, on core: 940/1095, c67_p405aN
# Processing cores, on core: 941/1095, c83_p405bN
# Processing cores, on core: 942/1095, c6_p415aN
# Processing cores, on core: 943/1095, c12_p415aT
# Processing cores, on core: 944/1095, c84_p415sN
# Processing cores, on core: 945/1095, c4_p146bN
# Processing cores, on core: 946/1095, c24_p226aT
# Processing cores, on core: 947/1095, c40_p144aT
# Processing cores, on core: 948/1095, c13_p146sT
# Processing cores, on core: 949/1095, c50_p143bN
# Processing cores, on core: 950/1095, c32_p33bN
# Processing cores, on core: 951/1095, c2_p61aT
# Processing cores, on core: 952/1095, c54_p61aT
# Processing cores, on core: 953/1095, c44_p86cT
# Processing cores, on core: 954/1095, c46_p86aN
# Processing cores, on core: 955/1095, c53_p86aN
# Processing cores, on core: 956/1095, c87_p86aN
# Processing cores, on core: 957/1095, c14_p144bT
# Processing cores, on core: 958/1095, c1_p108aN
# Processing cores, on core: 959/1095, c80_p108bN
# Processing cores, on core: 960/1095, c22_p112bN
# Processing cores, on core: 961/1095, c26_p112aN
# Processing cores, on core: 962/1095, c30_p112bT
# Processing cores, on core: 963/1095, c33_p112aT
# Processing cores, on core: 964/1095, c94_p86cN
# Processing cores, on core: 965/1095, c29_p119bT
# Processing cores, on core: 966/1095, c43_p112aT
# Processing cores, on core: 967/1095, c39_p143bN
# Processing cores, on core: 968/1095, c69_p142aT
# Processing cores, on core: 969/1095, c41_p142sT
# Processing cores, on core: 970/1095, c57_p124aN
# Processing cores, on core: 971/1095, c31_p124bT
# Processing cores, on core: 972/1095, c78_p124aN
# Processing cores, on core: 973/1095, c63_p123aN
# Processing cores, on core: 974/1095, c16_p123bN
# Processing cores, on core: 975/1095, c10_p123aN
# Processing cores, on core: 976/1095, c65_p119bT
# Processing cores, on core: 977/1095, c60_p119aN
# Processing cores, on core: 978/1095, c23_p124bN
# Processing cores, on core: 979/1095, c40_p461bT
# Processing cores, on core: 980/1095, c41_p464aN
# Processing cores, on core: 981/1095, c3_p464aN
# Processing cores, on core: 982/1095, c46_p461aT
# Processing cores, on core: 983/1095, c20_p461aT
# Processing cores, on core: 984/1095, c49_p454aT
# Processing cores, on core: 985/1095, c34_p460bT
# Processing cores, on core: 986/1095, c13_p460bT
# Processing cores, on core: 987/1095, c52_p459bN
# Processing cores, on core: 988/1095, c10_p459aN
# Processing cores, on core: 989/1095, c56_p454aT
# Processing cores, on core: 990/1095, c63_p460bT
# Processing cores, on core: 991/1095, c6_p468bN
# Processing cores, on core: 992/1095, c60_p472aN
# Processing cores, on core: 993/1095, c47_p468aN
# Processing cores, on core: 994/1095, c5_p469aN
# Processing cores, on core: 995/1095, c30_p469aN
# Processing cores, on core: 996/1095, c61_p469cN
# Processing cores, on core: 997/1095, c23_p470bT
# Processing cores, on core: 998/1095, c32_p470bT
# Processing cores, on core: 999/1095, c54_p470bT
# Processing cores, on core: 1000/1095, c8_p471aT
# Processing cores, on core: 1001/1095, c43_p471aT
# Processing cores, on core: 1002/1095, c48_p471aT
# Processing cores, on core: 1003/1095, c29_p472aN
# Processing cores, on core: 1004/1095, c58_p472bN
# Processing cores, on core: 1005/1095, c19_p454aT
# Processing cores, on core: 1006/1095, c16_p468aN
# Processing cores, on core: 1007/1095, c68_p453aN
# Processing cores, on core: 1008/1095, c55_p464bN
# Processing cores, on core: 1009/1095, c37_p453bN
# Processing cores, on core: 1010/1095, c62_p370aT
# Processing cores, on core: 1011/1095, c57_p374aN
# Processing cores, on core: 1012/1095, c59_p374bN
# Processing cores, on core: 1013/1095, c39_p378aT
# Processing cores, on core: 1014/1095, c42_p378aT
# Processing cores, on core: 1015/1095, c50_p378aT
# Processing cores, on core: 1016/1095, c14_p399bT
# Processing cores, on core: 1017/1095, c67_p453aN
# Processing cores, on core: 1018/1095, c25_p418aT
# Processing cores, on core: 1019/1095, c15_p421aT
# Processing cores, on core: 1020/1095, c66_p421aT
# Processing cores, on core: 1021/1095, c70_p421aT
# Processing cores, on core: 1022/1095, c4_p423aN
# Processing cores, on core: 1023/1095, c51_p399aT
# Processing cores, on core: 1024/1095, c38_p423aN
# Processing cores, on core: 1025/1095, c24_p423aT
# Processing cores, on core: 1026/1095, c9_p452aN
# Processing cores, on core: 1027/1095, c7_p452bN
# Processing cores, on core: 1028/1095, c33_p449aN
# Processing cores, on core: 1029/1095, c21_p449bN
# Processing cores, on core: 1030/1095, c45_p445bN
# Processing cores, on core: 1031/1095, c17_p452aN
# Processing cores, on core: 1032/1095, c18_p445eN
# Processing cores, on core: 1033/1095, c65_p433aT
# Processing cores, on core: 1034/1095, c27_p433aT
# Processing cores, on core: 1035/1095, c31_p430aN
# Processing cores, on core: 1036/1095, c64_p423aN
# Processing cores, on core: 1037/1095, c28_p445bN
# Processing cores, on core: 1038/1095, c58_p563bN
# Processing cores, on core: 1039/1095, c46_p563bT
# Processing cores, on core: 1040/1095, c35_p563bT
# Processing cores, on core: 1041/1095, c7_p563aN
# Processing cores, on core: 1042/1095, c36_p561bN
# Processing cores, on core: 1043/1095, c23_p561bT
# Processing cores, on core: 1044/1095, c26_p561aN
# Processing cores, on core: 1045/1095, c19_p561aN
# Processing cores, on core: 1046/1095, c13_p561aT
# Processing cores, on core: 1047/1095, c41_p559bN
# Processing cores, on core: 1048/1095, c34_p561aN
# Processing cores, on core: 1049/1095, c71_p563bN
# Processing cores, on core: 1050/1095, c33_p617aT
# Processing cores, on core: 1051/1095, c57_p568aT
# Processing cores, on core: 1052/1095, c60_p568aT
# Processing cores, on core: 1053/1095, c38_p609aT
# Processing cores, on core: 1054/1095, c44_p609aT
# Processing cores, on core: 1055/1095, c8_p613aN
# Processing cores, on core: 1056/1095, c28_p613bN
# Processing cores, on core: 1057/1095, c40_p613aN
# Processing cores, on core: 1058/1095, c10_p615bN
# Processing cores, on core: 1059/1095, c50_p615aT
# Processing cores, on core: 1060/1095, c56_p615aN
# Processing cores, on core: 1061/1095, c59_p615dN
# Processing cores, on core: 1062/1095, c24_p617bN
# Processing cores, on core: 1063/1095, c39_p559bN
# Processing cores, on core: 1064/1095, c32_p568aT
# Processing cores, on core: 1065/1095, c15_p559bN
# Processing cores, on core: 1066/1095, c43_p538aN
# Processing cores, on core: 1067/1095, c18_p556bT
# Processing cores, on core: 1068/1095, c62_p617aN
# Processing cores, on core: 1069/1095, c4_p516aN
# Processing cores, on core: 1070/1095, c45_p516aT
# Processing cores, on core: 1071/1095, c47_p516bN
# Processing cores, on core: 1072/1095, c61_p516aN
# Processing cores, on core: 1073/1095, c67_p516aT
# Processing cores, on core: 1074/1095, c27_p519aT
# Processing cores, on core: 1075/1095, c65_p519aT
# Processing cores, on core: 1076/1095, c72_p519aT
# Processing cores, on core: 1077/1095, c42_p523bN
# Processing cores, on core: 1078/1095, c49_p523aN
# Processing cores, on core: 1079/1095, c52_p523bT
# Processing cores, on core: 1080/1095, c55_p523aT
# Processing cores, on core: 1081/1095, c64_p523cN
# Processing cores, on core: 1082/1095, c37_p538aN
# Processing cores, on core: 1083/1095, c53_p538bN
# Processing cores, on core: 1084/1095, c63_p538bN
# Processing cores, on core: 1085/1095, c66_p538aN PIN
# Processing cores, on core: 1086/1095, c12_p540bN
# Processing cores, on core: 1087/1095, c16_p540bN
# Processing cores, on core: 1088/1095, c21_p540aT
# Processing cores, on core: 1089/1095, c25_p540aN PIN
# Processing cores, on core: 1090/1095, c31_p540aT
# Processing cores, on core: 1091/1095, c20_p551aN
# Processing cores, on core: 1092/1095, c30_p551bN
# Processing cores, on core: 1093/1095, c51_p551aN
# Processing cores, on core: 1094/1095, c14_p556bT
# Processing cores, on core: 1095/1095, c70_p556bT

# %%
df = pd.DataFrame.from_dict(new_sheet_data)
df.to_excel(fr"{root_dir}/master_sheet.xlsx",index=False)
